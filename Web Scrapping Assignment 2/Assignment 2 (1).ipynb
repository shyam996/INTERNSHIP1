# %% [markdown]
# ## Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Desktop\chromedriver.exe')

# %%
driver.get('https://www.naukri.com/')

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location = driver.find_element(By.XPATH,'/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input')
location.send_keys('Bangalore')

# %%
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    

location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd

df=pd.DataFrame({'Job_Title':job_title,'Job_Location':job_location,'Company_Name':company_name,'Experience_Required':experience_required})
df
# Out:
#                     Job_Title  \
# 0  Data Engineer/Data Analyst
# 1                Data Analyst
# 2                Data Analyst
# 3  Data Analyst - Contractual
# 4  Data Analyst - Contractual
# 5                Data Analyst
# 6    Procurement Data Analyst
# 7       Data Analyst, Grp 4.3
# 8       ExcelHER-Data Analyst
# 9                Data Analyst
#
#                                         Job_Location  \
# 0  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7                                Bangalore/Bengaluru
# 8  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...
# 9                                Bangalore/Bengaluru
#
# ...

# %% [markdown]
# ## Q2:Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.This task will be done in following steps:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Desktop\chromedriver.exe')

# %%
driver.get('https://www.naukri.com/')

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location = driver.find_element(By.XPATH,'/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input')
location.send_keys('Bangalore')

# %%
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]

# %%
title_tag = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tag[0:10]:
    title =i.text
    job_title.append(title)
    
location_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location =i.text
    job_location.append(location)
    
company_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company=i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
import pandas as pd

df = pd.DataFrame({'Job_title':job_title,'Job_Location':job_location,'Company_Name':company_name})
df
# Out:
#                                            Job_title  \
# 0  Data Science Professional - IBM SPSS Statistic...
# 1                            Data Science Specialist
# 2                   Analystics & Modeling Specialist
# 3                              Senior data scientist
# 4                                 Data Scientist_NLP
# 5                                     Data Scientist
# 6                    Machine Learning (AI) Architect
# 7       Manager - Innovations Hub - Machine Learning
# 8            Senior Engineer Consultant Data Science
# 9            Senior Engineer Consultant-Data Science
#
#                                         Job_Location           Company_Name
# 0  Bangalore/Bengaluru, Noida, Mumbai, Pune, Chennai  Hexaware Technologies
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...              Accenture
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...              Accenture
# 3  Bangalore/Bengaluru, Mumbai, Pune, Chennai, Gu...      Fractal Analytics
# ...

# %% [markdown]
# ## Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
# ## You have to use the location and salary filter.You have to scrape data for “Data Scientist” designation for first 10 job results.You have to scrape the job-title, job-location, company name, experience required.The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Desktop\chromedriver.exe')

# %%
driver.get('https://www.naukri.com/')

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
locn_tags= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]')
locn_tags.click()

# %%
sal_tags =driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[2]/div[2]/div[2]/label/p/span[1]')
sal_tags.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location =i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
import pandas as pd

df=pd.DataFrame({'Job_Title':job_title,'Job_Location':job_location,'Company_Name':company_name,'Experience_Required':experience_required})
df
# Out:
#                                            Job_Title  \
# 0                                     Data Scientist
# 1                              Junior Data Scientist
# 2                                     Data Scientist
# 3                              Junior Data Scientist
# 4                                     Data Scientist
# 5                                     Data Scientist
# 6                               Analyst-Data Science
# 7                               Analyst-Data Science
# 8                              Senior Data Scientist
# 9  Assistant Manager/Senior Manager - Data Scientist
#
#                                         Job_Location  \
# 0  Temp. WFH - Kochi/Cochin, Kolkata, Hyderabad/S...
# 1  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 2              Gurgaon/Gurugram, Bangalore/Bengaluru
# 3    Gurgaon/Gurugram, United States (USA), Bulgaria
# 4  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 5  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# ...

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:    1. Brand  2. ProductDescription  3. Price

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Desktop\chromedriver.exe')

# %%
driver.get('https://www.flipkart.com/')

# %%
products = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
products.send_keys("sunglasses")

# %%
search = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand =[]
product_des =[]
price =[]
discount = []

# %%
brand_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags:
    brnd = i.text
    brand.append(brnd)
    
product_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_tags:
    prod = i.text
    product_des.append(prod)
    
price_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags:
    pri = i.text
    price.append(pri)
    
discount_tags = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discount_tags:
    disc = i.text
    discount.append(disc)

# %%
print(len(brand),len(product_des),len(price),len(discount))
# Out:
# 40 40 40 40

# %%
df_1 = pd.DataFrame({'Brand':brand,'Product_description':product_des,'Price':price,'Discount':discount})
df_1
# Out:
#                 Brand                                Product_description  \
# 0       VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...
# 1       VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)
# 2           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 3              PIRASO       UV Protection Aviator Sunglasses (Free Size)
# 4           Elligator   UV Protection, Mirrored Wayfarer Sunglasses (54)
# 5   SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 6            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 7       VINCENT CHASE    by Lenskart UV Protection Round Sunglasses (58)
# 8              PIRASO           UV Protection Clubmaster Sunglasses (54)
# 9              PIRASO              UV Protection Aviator Sunglasses (58)
# 10          New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 11      VINCENT CHASE             UV Protection Wayfarer Sunglasses (62)
# ...

# %%
brands=[]

# %%
start = 0
end  = 3

for page in range(start,end):
    brandss = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brandss[0:100]:
        brands.append(i.text)
    next_button=driver.find_elements(By.XPATH,"//a[@class='_1LKTO3']")

# %%
brands
# Out:
# ['VINCENT CHASE',
#  'VINCENT CHASE',
#  'Elligator',
#  'PIRASO',
#  'Elligator',
#  'SHAAH COLLECTIONS',
#  'Fastrack',
#  'VINCENT CHASE',
#  'PIRASO',
#  'PIRASO',
#  'New Specs',
#  'VINCENT CHASE',
#  'NuVew',
#  'Fastrack',
#  'Fastrack',
#  'Eyewearlabs',
#  'Elligator',
#  'Fastrack',
#  'NuVew',
#  'AISLIN',
#  'Elligator',
#  'PIRASO',
#  'Fastrack',
#  'AISLIN',
#  'PIRASO',
#  'Elligator',
#  'PIRASO',
#  'Eyewearlabs',
#  'Fastrack',
#  'PIRASO',
#  'Fastrack',
#  'Velocity Eyewear',
#  'Elligator',
#  'PIRASO',
#  'Elligator',
#  'VINCENT CHASE',
#  'NuVew',
#  'PIRASO',
#  'SUNBEE',
#  'Silver Kartz',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'Elligator',
#  'PIRASO',
#  'Elligator',
#  'SHAAH COLLECTIONS',
#  'Fastrack',
#  'VINCENT CHASE',
#  'PIRASO',
#  'PIRASO',
#  'New Specs',
#  'VINCENT CHASE',
#  'NuVew',
#  'Fastrack',
#  'Fastrack',
#  'Eyewearlabs',
#  'Elligator',
#  'Fastrack',
#  'NuVew',
#  'AISLIN',
#  'Elligator',
#  'PIRASO',
#  'Fastrack',
# ...

# %%
product_desc=[]

# %%
start = 0
end  = 3

for page in range(start,end):
    products = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in products[0:100]:
        product_desc.append(i.text)
    next_button=driver.find_elements(By.XPATH,"//a[@class='_1LKTO3']")

# %%
product_desc
# Out:
# ['by Lenskart Polarized, UV Protection Retro Square Sungl...',
#  'Polarized, UV Protection Round Sunglasses (50)',
#  'UV Protection Cat-eye, Retro Square, Oval, Round Sungla...',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection, Mirrored Wayfarer Sunglasses (54)',
#  'UV Protection, Polarized, Mirrored Rectangular Sunglass...',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'by Lenskart UV Protection Round Sunglasses (58)',
#  'UV Protection Clubmaster Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (58)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (62)',
#  'UV Protection Sports Sunglasses (65)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (58)',
#  'Polarized, UV Protection Aviator Sunglasses (56)',
#  'UV Protection Oval Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (Free Size)',
# ...

# %%
prices=[]

# %%
start = 0
end  = 3

for page in range(start,end):
    pricess = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in pricess[0:100]:
        prices.append(i.text)
    next_button=driver.find_elements(By.XPATH,"//a[@class='_1LKTO3']")

# %%
prices
# Out:
# ['₹1,061',
#  '₹929',
#  '₹149',
#  '₹268',
#  '₹179',
#  '₹185',
#  '₹644',
#  '₹929',
#  '₹224',
#  '₹274',
#  '₹265',
#  '₹899',
#  '₹129',
#  '₹509',
#  '₹909',
#  '₹1,489',
#  '₹179',
#  '₹544',
#  '₹99',
#  '₹786',
#  '₹149',
#  '₹211',
#  '₹585',
#  '₹485',
#  '₹182',
#  '₹149',
#  '₹212',
#  '₹1,470',
#  '₹739',
#  '₹214',
#  '₹739',
#  '₹1,126',
#  '₹129',
#  '₹180',
#  '₹179',
#  '₹899',
#  '₹129',
#  '₹173',
#  '₹179',
#  '₹232',
#  '₹1,061',
#  '₹929',
#  '₹149',
#  '₹268',
#  '₹179',
#  '₹185',
#  '₹644',
#  '₹929',
#  '₹224',
#  '₹274',
#  '₹265',
#  '₹899',
#  '₹129',
#  '₹509',
#  '₹909',
#  '₹1,489',
#  '₹179',
#  '₹544',
#  '₹99',
#  '₹786',
#  '₹149',
#  '₹211',
#  '₹585',
#  '₹485',
#  '₹182',
#  '₹149',
#  '₹212',
#  '₹1,470',
#  '₹739',
#  '₹214',
#  '₹739',
#  '₹1,126',
#  '₹129',
#  '₹180',
#  '₹179',
#  '₹899',
#  '₹129',
#  '₹173',
#  '₹179',
#  '₹232',
#  '₹1,061',
#  '₹929',
#  '₹149',
#  '₹268',
#  '₹179',
#  '₹185',
#  '₹644',
#  '₹929',
#  '₹224',
# ...

# %%
discounts =[]

# %%
start = 0
end  = 3

for page in range(start,end):
    discountss = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in discountss[0:100]:
        discounts.append(i.text)
    next_button=driver.find_elements(By.XPATH,"//a[@class='_1LKTO3']")

# %%
discounts
# Out:
# ['46% off',
#  '53% off',
#  '75% off',
#  '83% off',
#  '82% off',
#  '89% off',
#  '41% off',
#  '53% off',
#  '85% off',
#  '89% off',
#  '86% off',
#  '55% off',
#  '86% off',
#  '43% off',
#  '35% off',
#  '46% off',
#  '88% off',
#  '45% off',
#  '88% off',
#  '78% off',
#  '85% off',
#  '86% off',
#  '46% off',
#  '68% off',
#  '90% off',
#  '85% off',
#  '86% off',
#  '47% off',
#  '26% off',
#  '86% off',
#  '26% off',
#  '24% off',
#  '74% off',
#  '88% off',
#  '88% off',
#  '55% off',
#  '82% off',
#  '89% off',
#  '82% off',
#  '76% off',
#  '46% off',
#  '53% off',
#  '75% off',
#  '83% off',
#  '82% off',
#  '89% off',
#  '41% off',
#  '53% off',
#  '85% off',
#  '89% off',
#  '86% off',
#  '55% off',
#  '86% off',
#  '43% off',
#  '35% off',
#  '46% off',
#  '88% off',
#  '45% off',
#  '88% off',
#  '78% off',
#  '85% off',
#  '86% off',
#  '46% off',
#  '68% off',
#  '90% off',
#  '85% off',
#  '86% off',
#  '47% off',
#  '26% off',
#  '86% off',
#  '26% off',
# ...

# %%
df = pd.DataFrame({'Brand':brands,'Product_Description':product_desc,'Price':prices,'Discount':discounts})
df
# Out:
#              Brand                                Product_Description   Price  \
# 0    VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...  ₹1,061
# 1    VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)    ₹929
# 2        Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...    ₹149
# 3           PIRASO       UV Protection Aviator Sunglasses (Free Size)    ₹268
# 4        Elligator   UV Protection, Mirrored Wayfarer Sunglasses (54)    ₹179
# ..             ...                                                ...     ...
# 115  VINCENT CHASE  by Lenskart Polarized, UV Protection Rectangul...    ₹899
# 116          NuVew    UV Protection, Mirrored Aviator Sunglasses (57)    ₹129
# 117         PIRASO           UV Protection Over-sized Sunglasses (60)    ₹173
# 118         SUNBEE   UV Protection Rectangular Sunglasses (Free Size)    ₹179
# 119   Silver Kartz      UV Protection Wayfarer Sunglasses (Free Size)    ₹232
#
#     Discount
# 0    46% off
# ...

# %%
df.head(100)
# Out:
#             Brand                                Product_Description   Price  \
# 0   VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...  ₹1,061
# 1   VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)    ₹929
# 2       Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...    ₹149
# 3          PIRASO       UV Protection Aviator Sunglasses (Free Size)    ₹268
# 4       Elligator   UV Protection, Mirrored Wayfarer Sunglasses (54)    ₹179
# ..            ...                                                ...     ...
# 95    Eyewearlabs   Polarized, UV Protection Aviator Sunglasses (56)  ₹1,489
# 96      Elligator                 UV Protection Oval Sunglasses (54)    ₹179
# 97       Fastrack       UV Protection Aviator Sunglasses (Free Size)    ₹544
# 98          NuVew   UV Protection, Mirrored Wayfarer Sunglasses (57)     ₹99
# 99         AISLIN  Toughened Glass Lens, UV Protection Aviator Su...    ₹786
#
#    Discount
# 0   46% off
# 1   53% off
# ...

# %% [markdown]
# ## Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Desktop\chromedriver.exe')

# %%
driver.get('https://www.flipkart.com/')

# %%
products = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
products.send_keys('iphone11')

# %%
search = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
sample = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[4]/div/div/div/a/div[2]/div[1]/div[1]')
sample.click()

# %%
rating = []

# %%
start=0
end=13

for page in range(start,end):
    ratings=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in ratings[0:100]:
        rating.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')

# %%
print(len(rating))
# Out:
# 104

# %%
review = []

# %%
start=0
end=13

for page in range(start,end):
    reviews=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in reviews[0:100]:
        review.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')

# %%
summary = []

# %%
start=0
end=13

for page in range(start,end):
    summarys=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in summarys[0:100]:
        summary.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')

# %%
print(len(rating),len(summary),len(review))
# Out:
# 104 104 104

# %%
df = pd.DataFrame({'Rating':rating,'Review_summary':summary,'Full_Review':review})
df
# Out:
#     Rating Review_summary                                        Full_Review
# 0        5              5  After using 3 years mobile review. Excellent &...
# 1        5              5                  Product was good, worked perfect.
# 2        4              4  impressively Nice......\nOne of the greatest i...
# 3        5              5                         Nice products thanks flkat
# 4        5              5  Really satisfied with the Product I received.....
# ..     ...            ...                                                ...
# 99       5              5                         Nice products thanks flkat
# 100      5              5  Really satisfied with the Product I received.....
# 101      5              5  Best in Iphone series in all feature ! Battery...
# 102      5              5  Fast performance to previous iPhone x\nGood ca...
# 103      5              5           Awesome product ❤️❤️\nThank you Flipkart
#
# [104 rows x 3 columns]

# %%
df.head(100)
# Out:
#    Rating Review_summary                                        Full_Review
# 0       5              5  After using 3 years mobile review. Excellent &...
# 1       5              5                  Product was good, worked perfect.
# 2       4              4  impressively Nice......\nOne of the greatest i...
# 3       5              5                         Nice products thanks flkat
# 4       5              5  Really satisfied with the Product I received.....
# ..    ...            ...                                                ...
# 95      5              5           Awesome product ❤️❤️\nThank you Flipkart
# 96      5              5  After using 3 years mobile review. Excellent &...
# 97      5              5                  Product was good, worked perfect.
# 98      4              4  impressively Nice......\nOne of the greatest i...
# 99      5              5                         Nice products thanks flkat
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in thesearch field.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Desktop\chromedriver.exe')

# %%
driver.get('https://www.flipkart.com/')

# %%
prod = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
prod.send_keys('sneakers')

# %%
search = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand=[]

# %%
start=0
end=3

for page in range(start,end):
    brands=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brands[0:100]:
        brand.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')

# %%
brand
# Out:
# ['Labbin',
#  'RapidBox',
#  'SFR',
#  'aadi',
#  'AMICO',
#  'Labbin',
#  'BIRDE',
#  'RapidBox',
#  'Kraasa',
#  'BIRDE',
#  'Labbin',
#  'aadi',
#  'BIRDE',
#  'aadi',
#  'aadi',
#  'BIRDE',
#  'Shozie',
#  'KNIGHT WALKERS',
#  'aadi',
#  'Magnolia',
#  'Footox',
#  'Deals4you',
#  'AMICO',
#  'BIRDE',
#  'Xtoon',
#  'Magnolia',
#  'Shozie',
#  'Deals4you',
#  'asian',
#  'RED TAPE',
#  'Deals4you',
#  'Deals4you',
#  'RED TAPE',
#  'BIRDE',
#  'World Wear Footwear',
#  'World Wear Footwear',
#  'Shozie',
#  'AIRBELL',
#  'BIRDE',
#  'SFR',
#  'Labbin',
#  'RapidBox',
#  'SFR',
#  'aadi',
#  'AMICO',
#  'Labbin',
#  'BIRDE',
#  'RapidBox',
#  'Kraasa',
#  'BIRDE',
#  'Labbin',
#  'aadi',
#  'BIRDE',
#  'aadi',
#  'aadi',
#  'BIRDE',
#  'Shozie',
#  'KNIGHT WALKERS',
#  'aadi',
#  'Magnolia',
#  'Footox',
#  'Deals4you',
#  'AMICO',
#  'BIRDE',
#  'Xtoon',
#  'Magnolia',
#  'Shozie',
#  'Deals4you',
#  'asian',
#  'RED TAPE',
#  'Deals4you',
#  'Deals4you',
#  'RED TAPE',
# ...

# %%
print(len(brand))
# Out:
# 120

# %%
prod_des =[]

# %%
start = 0
end = 3

for page in range(start,end):
    products= driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in products[0:100]:
        prod_des.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')

# %%
price =[]

# %%
start = 0
end = 3

for page in range(start,end):
    prices=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in prices[0:100]:
        price.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')

# %%
print(len(brand),len(prod_des),len(price))
# Out:
# 120 120 120

# %%
df = pd.DataFrame({'Brand':brand,'Product_Description':prod_des,'Price':price})
df
# Out:
#                    Brand                                Product_Description  \
# 0                 Labbin  Casual Sneakers ColourFul Block Shoes For Boys...
# 1               RapidBox                                   Sneakers For Men
# 2                    SFR  2006 Trenddy Fashion Sporty Casuals Sneakers R...
# 3                   aadi  Synthetic| Lightweight| Premiun| Comfort| Summ...
# 4                  AMICO                                   Sneakers For Men
# ..                   ...                                                ...
# 115  World Wear Footwear  Latest Collection-1215 Stylish Casual Sports S...
# 116               Shozie  Stylish Walking Partywear Sneakers Casual Shoe...
# 117              AIRBELL  Mesh | Lightweight | Premium | Comfort | Trend...
# 118                BIRDE            Combo Pack of 2 Sports Sneakers For Men
# 119                  SFR                                   Sneakers For Men
#
#     Price
# 0    ₹694
# 1    ₹571
# 2    ₹299
# ...

# %%
df.head(100)
# Out:
#              Brand                                Product_Description Price
# 0           Labbin  Casual Sneakers ColourFul Block Shoes For Boys...  ₹694
# 1         RapidBox                                   Sneakers For Men  ₹571
# 2              SFR  2006 Trenddy Fashion Sporty Casuals Sneakers R...  ₹299
# 3             aadi  Synthetic| Lightweight| Premiun| Comfort| Summ...  ₹399
# 4            AMICO                                   Sneakers For Men  ₹387
# ..             ...                                                ...   ...
# 95           BIRDE  Premium Sports Shoes For Men Pack Of 2 Sneaker...  ₹499
# 96          Shozie     Women Sneakers Casual Shoes Sneakers For Women  ₹499
# 97  KNIGHT WALKERS                                   Sneakers For Men  ₹570
# 98            aadi                                   Sneakers For Men  ₹349
# 99        Magnolia  Modern Trendy Sneakers boot Sneakers Sneakers ...  ₹399
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” as shown in the below image:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Desktop\chromedriver.exe')

# %%
driver.get('https://www.amazon.in/')

# %%
prod = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
prod.send_keys('Laptop')

# %%
search = driver.find_element(By.CLASS_NAME,"nav-right")
search.click()

# %%
cpu_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[6]/li[10]/span/a/span')
cpu_tags.click()

# %%
title=[]
rating=[]
price=[]

# %%
title_tag = driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in title_tag[0:10]:
    titles=i.text
    title.append(titles)
    
rating_tag = driver.find_elements(By.XPATH,'//span[@class="a-size-base"]')
for i in rating_tag[0:10]:
    ratings=i.text
    rating.append(ratings)
    
price_tag = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tag[0:10]:
    prices=i.text
    price.append(prices)

# %%
print(len(title),len(rating),len(price))
# Out:
# 10 10 10

# %%
df = pd.DataFrame({'Title':title,'Ratings':rating,'Price':price})
df
# Out:
#                                                Title Ratings     Price
# 0  HP Victus Gaming Latest 12th Gen Intel Core i7...     4.3    79,990
# 1  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...     4.3    31,592
# 2  (Renewed) HP 840g3 Elitebook 14 Inch Screen La...     3.0  1,00,990
# 3  ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) F...     4.4    92,990
# 4  ASUS TUF Dash F15, Intel Core i7-12650H 12th G...     4.0    31,490
# 5  (Renewed) HP ELITEBOOK 840 G5 (Core i7 8th GEN...     4.0    84,990
# 6  ASUS Vivobook S15 OLED 2022, 15.6" 39.62 cms F...     4.1    94,990
# 7  ASUS TUF Gaming F15 (2022), 15.6" (39.62 cms) ...     3.7    84,910
# 8  Dell Inspiron 5320 Laptop, Intel i7-1260P, 16G...     4.3    83,990
# 9  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...     2.0    29,990

# %% [markdown]
# # Q8: Write a python program to scrape data for Top 1000 Quotes of All Time

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Desktop\chromedriver.exe')

# %%
driver.get('https://www.azquotes.com/')

# %%
search = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
search.click()

# %%
quote = []

# %%
start =0
end = 10

for page in range(start,end):
    quotes=driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in quotes[0:1000]:
        quote.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//li[@class="next"]')

# %%
print(len(quote))
# Out:
# 1000

# %%
author =[]

# %%
start = 0
end = 10

for page in range(start,end):
    authors=driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in authors[0:1000]:
        author.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//li[@class="next"]')

# %%
type_quote=[]

# %%
start = 0
end = 10

for page in range(start,end):
    types_quote =driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in types_quote[0:1000]:
        type_quote.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//li[@class="next"]')

# %%
print(len(quote),len(author),len(type_quote))
# Out:
# 1000 1000 1000

# %%
df = pd.DataFrame({'Quote':quote,'Author':author,'Types_Of_Quote':type_quote})
df
# Out:
#                                                  Quote                Author  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
# ...

# %% [markdown]
# # Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Desktop\chromedriver.exe')

# %%
driver.get('https://www.jagranjosh.com/')

# %%
gk_tag = driver.find_element(By.XPATH,'/html/body/div/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[9]/a')
gk_tag.click()

# %%
list_pm = driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
list_pm.click()

# %%
name = []

# %%
name_tag = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for i in name_tag:
    names=i.text
    name.append(names)

# %%
name
# Out:
# ['Jawahar Lal Nehru',
#  'Gulzarilal Nanda (Acting)',
#  'Lal Bahadur Shastri',
#  'Gulzari Lal Nanda  (Acting)',
#  'Indira Gandhi',
#  'Morarji Desai',
#  'Charan Singh',
#  'Indira Gandhi',
#  'Rajiv Gandhi',
#  'V. P. Singh',
#  'Chandra Shekhar',
#  'P. V. Narasimha Rao',
#  'Atal Bihari Vajpayee',
#  'H. D. Deve Gowda',
#  'Inder Kumar Gujral',
#  'Atal Bihari Vajpayee',
#  'Manmohan Singh',
#  'Narendra Modi']

# %%
born=[]
office=[]
remark=[]

# %%
born_tag = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in born_tag:
    borns=i.text
    born.append(borns)
    
office_tag = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]/p')
for i in office_tag[0:18]:
    offices=i.text
    office.append(offices)
    
remark_tag = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for i in remark_tag:
    remarks=i.text
    remark.append(remarks)

# %%
print(len(name),len(born),len(office),len(remark))
# Out:
# 18 18 18 18

# %%
df = pd.DataFrame({'Name':name,'BorN_Dead':born,'Term_Of_Office':office,'Remarks':remark})
df
# Out:
#                            Name     BorN_Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                         Term_Of_Office  \
# ...

# %% [markdown]
# # Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e.Car name and Price) from https://www.motor1.com/

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'C:\Users\Administrator\Desktop\chromedriver.exe')

# %%
driver.get('https://www.motor1.com/')

# %%
lists = driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[6]/ul/li[1]/a')
lists.click()

# %%
expensive = driver.find_element(By.XPATH,'/html/body/div[3]/div[8]/div[1]/div[1]/div/div/div[8]/div/div[1]/h3/a')
expensive.click()

# %%
name = []

# %%
name_tag = driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in name_tag:
    names=i.text
    name.append(names)

# %%
prices =[]

prices_50expcars = driver.find_elements(By.XPATH,"//strong")
for i in prices_50expcars:
    prices.append(i.text)

# %%
prices
# Out:
# ['Price: $1.3 Million',
#  'Price: $1.4 Million',
#  'Price: $1.4 Million',
#  '',
#  'Price: $1.7 Million',
#  'Price: $1.7 Million',
#  'Price: $1.7 Million',
#  'Price: $1.7 Million',
#  'Price: $1.7 Million',
#  'Price: $1.7 Million',
#  'Price: $1.8 Million',
#  'Price: $1.9 Million',
#  'Price: $1.9 Million',
#  'Price: $2.0 Million',
#  'Price: $2.0 Million',
#  'Price: $2.0 Million*',
#  'Price: $2.1 Million',
#  'Price: $2.3 Million',
#  'Price: $2.3 Million',
#  'Price: $2.3 Million',
#  'Price: $2.4 Million',
#  'Price: $2.5 Million',
#  'Price: $2.5 Million',
#  'Price: $2.6 Million',
#  'Price: $2.6 Million',
#  'Price: $2.6 Million',
#  'Price: $2.7 Million',
#  'Price: $3.0 Million',
#  '$3.0 Million',
#  'Price: $3.0 Million',
#  'Price: $3.2 Million',
#  'Price: $3.4 Million',
#  '$3.5 Million',
#  'Price: $3.5 Million',
#  'Price: $3.6 Million',
#  'Price: $3.6 million',
#  'Price: $3.7 Million',
#  'Price: $3.9 Million',
#  'Price: $4.5 Million',
# ...

# %%
print(len(name),len(prices))
# Out:
# 51 51

# %%
df = pd.DataFrame({'Car_Name':name,'Price':prices})
df
# Out:
#                             Car_Name                        Price
# 0                      De Tomaso P72          Price: $1.3 Million
# 1                  Ferrari LaFerrari          Price: $1.4 Million
# 2                      Pagani Huayra          Price: $1.4 Million
# 3                       McLaren Elva
# 4                        Czinger 21C          Price: $1.7 Million
# 5                      Ferrari Monza          Price: $1.7 Million
# 6                 Gordon Murray T.33          Price: $1.7 Million
# 7                  Koenigsegg Gemera          Price: $1.7 Million
# 8                        Zenvo TSR-S          Price: $1.7 Million
# 9                 Hennessey Venom F5          Price: $1.7 Million
# 10                   Bentley Bacalar          Price: $1.8 Million
# 11     Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 12            Bentley Mulliner Batur          Price: $1.9 Million
# 13                      Deus Vayanne          Price: $2.0 Million
# ...

# %%
df.head(50)
# Out:
#                            Car_Name                 Price
# 0                     De Tomaso P72   Price: $1.3 Million
# 1                 Ferrari LaFerrari   Price: $1.4 Million
# 2                     Pagani Huayra   Price: $1.4 Million
# 3                      McLaren Elva
# 4                       Czinger 21C   Price: $1.7 Million
# 5                     Ferrari Monza   Price: $1.7 Million
# 6                Gordon Murray T.33   Price: $1.7 Million
# 7                 Koenigsegg Gemera   Price: $1.7 Million
# 8                       Zenvo TSR-S   Price: $1.7 Million
# 9                Hennessey Venom F5   Price: $1.7 Million
# 10                  Bentley Bacalar   Price: $1.8 Million
# 11    Hispano Suiza Carmen Boulogne   Price: $1.9 Million
# 12           Bentley Mulliner Batur   Price: $1.9 Million
# 13                     Deus Vayanne   Price: $2.0 Million
# 14                      SSC Tuatara   Price: $2.0 Million
# 15                      Lotus Evija  Price: $2.0 Million*
# ...
