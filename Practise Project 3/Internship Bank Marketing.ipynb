# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\Administrator\Desktop\dataset5-main\termdeposit_train.csv')
df
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...

# %%
df.head(20)
# Out:
#        ID  age          job   marital  education default  balance housing  \
# 0   26110   56       admin.   married    unknown      no     1933      no
# 1   40576   31      unknown   married  secondary      no        3      no
# 2   15320   27     services   married  secondary      no      891     yes
# 3   43962   57   management  divorced   tertiary      no     3287      no
# 4   29842   31   technician   married  secondary      no      119     yes
# 5   29390   33   management    single   tertiary      no        0     yes
# 6   40444   56      retired   married  secondary      no     1044      no
# 7   40194   50   technician    single  secondary      no     1811      no
# 8   29824   45  blue-collar  divorced  secondary      no     1951     yes
# 9   44676   35       admin.   married  secondary      no     1204      no
# 10  14699   36     services  divorced  secondary     yes        0      no
# 11  30180   35  blue-collar   married  secondary      no     -151     yes
# ...

# %%
df.isnull().sum()
# Out:
# ID            0
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          31647 non-null  int64
#  1   age         31647 non-null  int64
#  2   job         31647 non-null  object
#  3   marital     31647 non-null  object
#  4   education   31647 non-null  object
#  5   default     31647 non-null  object
#  6   balance     31647 non-null  int64
#  7   housing     31647 non-null  object
#  8   loan        31647 non-null  object
#  9   contact     31647 non-null  object
#  10  day         31647 non-null  int64
#  11  month       31647 non-null  object
#  12  duration    31647 non-null  int64
#  13  campaign    31647 non-null  int64
#  14  pdays       31647 non-null  int64
#  15  previous    31647 non-null  int64
#  16  poutcome    31647 non-null  object
#  17  subscribed  31647 non-null  object
# dtypes: int64(8), object(10)
# memory usage: 4.3+ MB

# %%
df.dtypes
# Out:
# ID             int64
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# subscribed    object
# dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'subscribed'],
#       dtype='object')

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 26110    1
# 13339    1
# 39681    1
# 15135    1
# 26037    1
#         ..
# 1247     1
# 15584    1
# 25376    1
# 38699    1
# 14156    1
# Name: ID, Length: 31647, dtype: int64
#
#
# 32    1457
# 31    1417
# 33    1406
# 34    1321
# 35    1314
#       ...
# 92       1
# 95       1
# 93       1
# 94       1
# 90       1
# Name: age, Length: 76, dtype: int64
#
#
# blue-collar      6842
# management       6639
# technician       5307
# admin.           3631
# services         2903
# retired          1574
# self-employed    1123
# entrepreneur     1008
# unemployed        905
# housemaid         874
# student           635
# unknown           206
# Name: job, dtype: int64
#
#
# married     19095
# single       8922
# divorced     3630
# Name: marital, dtype: int64
#
#
# secondary    16224
# tertiary      9301
# primary       4808
# unknown       1314
# Name: education, dtype: int64
#
#
# no     31062
# yes      585
# Name: default, dtype: int64
#
#
#  0        2470
# ...

# %% [markdown]
# Hence,we will drop ID column,as there is unique values is there.

# %%
df.drop('ID',axis=1,inplace=True)

# %%
df.head(10)
# Out:
#    age          job   marital  education default  balance housing loan  \
# 0   56       admin.   married    unknown      no     1933      no   no
# 1   31      unknown   married  secondary      no        3      no   no
# 2   27     services   married  secondary      no      891     yes   no
# 3   57   management  divorced   tertiary      no     3287      no   no
# 4   31   technician   married  secondary      no      119     yes   no
# 5   33   management    single   tertiary      no        0     yes   no
# 6   56      retired   married  secondary      no     1044      no   no
# 7   50   technician    single  secondary      no     1811      no   no
# 8   45  blue-collar  divorced  secondary      no     1951     yes   no
# 9   35       admin.   married  secondary      no     1204      no   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   19   nov        44         2     -1         0  unknown
# ...

# %%
categorical_col =[]
for i in df.dtypes.index:
    if df.dtypes[i] == "object":
        categorical_col.append(i)
print('Categorical Columns : ', categorical_col)
print('\n')



numerical_col =[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print('Numerical Columns : ', numerical_col)
print('\n')
# Out:
# Categorical Columns :  ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'subscribed']
#
#
# Numerical Columns :  ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
df.nunique().to_frame('No. of unique values')
# Out:
#             No. of unique values
# age                           76
# job                           12
# marital                        3
# education                      4
# default                        2
# balance                     6326
# housing                        2
# loan                           2
# contact                        3
# day                           31
# month                         12
# duration                    1454
# campaign                      45
# pdays                        509
# previous                      38
# poutcome                       4
# subscribed                     2

# %%
df['subscribed'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %% [markdown]
# Here,2 unique values are there for Target colun,Hence it is a classification problem.

# %%
df['subscribed'].value_counts()
# Out:
# no     27932
# yes     3715
# Name: subscribed, dtype: int64

# %% [markdown]
# Here,no stands for customers not getting subscribed for fixed deposit,yes stands for getting subscribed for fixed deposit.

# %%
df.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# subscribed    object
# dtype: object

# %% [markdown]
# Now we have converted all Object datatypes into float datatypes.

# %%
print('Total Duplicates Rows are ',df.duplicated().sum())
# Out:
# Total Duplicates Rows are  0

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  31647.000000   31647.000000  31647.000000  31647.000000  31647.000000
# mean      40.957247    1363.890258     15.835466    258.113534      2.765697
# std       10.625134    3028.304293      8.337097    257.118973      3.113830
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      73.000000      8.000000    104.000000      1.000000
# 50%       39.000000     450.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1431.000000     21.000000    318.500000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  31647.000000  31647.000000
# mean      39.576042      0.574272
# std       99.317592      2.422529
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# 1) The counts of all columns are same.
#
# 2) The mean > median (50%) in Age,Balance,Duration,Campaign,pdays,previous columns which means data is skewed to right.
#
# 3) The mean < median(50%) in  Day which means data is skewed to left.
#
# 4) Remaining Columns all are Categorical.
#
# 5) There is max difference between 75% and max in Age,Balance,Day,Duration,Campaigns,pdays,previous columns which means outliers is present.

# %% [markdown]
# From the above plot we can say that Age,default,balance,duration,campaign,pdays,previous columns data is skewed to right.We did not check distribution in Target Columns.

# %%
plt.figure(figsize=(25,15), facecolor='white')
plotnumber=1
for col in numerical_col:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[col], color='r')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above distplot, we can say that data is skewd to right in age,balance,duration,campaign,pdays,previous and day looks normal.

# %%
ax= sns.countplot(x='job', data=df)
print(df['job'].value_counts())
# Out:
# blue-collar      6842
# management       6639
# technician       5307
# admin.           3631
# services         2903
# retired          1574
# self-employed    1123
# entrepreneur     1008
# unemployed        905
# housemaid         874
# student           635
# unknown           206
# Name: job, dtype: int64

# %% [markdown]
# From the above count plot we can say that counts of blue-collar is more than other types of job.

# %%
ax= sns.countplot(x='marital', data=df)
print(df['marital'].value_counts())
# Out:
# married     19095
# single       8922
# divorced     3630
# Name: marital, dtype: int64

# %% [markdown]
# From the above we can say that count of married is more than count of single and divorced.

# %%
ax= sns.countplot(x='education', data=df)
print(df['education'].value_counts())
# Out:
# secondary    16224
# tertiary      9301
# primary       4808
# unknown       1314
# Name: education, dtype: int64

# %% [markdown]
# From above we can say that count of secondary education is more than other types of education.

# %%
ax= sns.countplot(x='default', data=df)
print(df['default'].value_counts())
# Out:
# no     31062
# yes      585
# Name: default, dtype: int64

# %% [markdown]
# The count of no default is more than count of default.

# %%
ax= sns.countplot(x='housing', data=df)
print(df['housing'].value_counts())
# Out:
# yes    17584
# no     14063
# Name: housing, dtype: int64

# %% [markdown]
# The count of those who are having housing is more than type of those who are not having housing.

# %%
ax= sns.countplot(x='loan', data=df)
print(df['loan'].value_counts())
# Out:
# no     26516
# yes     5131
# Name: loan, dtype: int64

# %% [markdown]
# The count of those who are not having loan is more than count of  those who are having loan

# %%
ax= sns.countplot(x='contact', data=df)
print(df['contact'].value_counts())
# Out:
# cellular     20423
# unknown       9177
# telephone     2047
# Name: contact, dtype: int64

# %% [markdown]
# The count of Cellular is higher than other types of contact

# %%
ax= sns.countplot(x='month', data=df)
print(df['month'].value_counts())
# Out:
# may    9669
# jul    4844
# aug    4333
# jun    3738
# nov    2783
# apr    2055
# feb    1827
# jan     977
# oct     512
# sep     410
# mar     342
# dec     157
# Name: month, dtype: int64

# %% [markdown]
# The count of May month is higher than count of other types of month.

# %%
ax= sns.countplot(x='poutcome', data=df)
print(df['poutcome'].value_counts())
# Out:
# unknown    25929
# failure     3362
# other       1288
# success     1068
# Name: poutcome, dtype: int64

# %% [markdown]
# The count of Unknown is higher than count of other types of poutcome

# %%
ax= sns.countplot(x='subscribed', data=df)
print(df['subscribed'].value_counts())
# Out:
# no     27932
# yes     3715
# Name: subscribed, dtype: int64

# %% [markdown]
# The count of those who are not subscribed is more than count of those who subscribed.

# %%
sns.catplot(x='job',col='subscribed',kind='count',data=df)
plt.show()

# %%
sns.catplot(x='marital',col='subscribed',kind='count',data=df)
plt.show()

# %% [markdown]
# Those who have subscribed count of married is higher than ohers.Similarly,those who have no subscribed count of married is higher than other.

# %%
sns.catplot(x='education',col='subscribed',kind='count',data=df)
plt.show()

# %% [markdown]
# Secondary education those having not subscribed is higher than others,similarly,secondary decucation is higher those who have subscribed.

# %%
sns.catplot(x='default',col='subscribed',kind='count',data=df)
plt.show()

# %% [markdown]
# In both the conditions no default is higher than default.

# %%
sns.catplot(x='housing',col='subscribed',kind='count',data=df)
plt.show()

# %% [markdown]
# Those who have not subscribed has housing greater . those who have subscribed has no house greater than those who have housing.

# %%
sns.catplot(x='loan',col='subscribed',kind='count',data=df)
plt.show()

# %% [markdown]
# In both the conditions those having no loan not subscribed is higher than those having loan getting subscribed.

# %%
sns.catplot(x='contact',col='subscribed',kind='count',data=df)
plt.show()

# %% [markdown]
# In both conditions for subscribed cellular contact is higher than other type of contacts those who have subscribed.

# %%
sns.catplot(x='month',col='subscribed',kind='count',data=df)
plt.show()

# %% [markdown]
# In both condition May month getting not subscribed is higher than other types those getting subscribed.

# %%
sns.catplot(x='poutcome',col='subscribed',kind='count',data=df)
plt.show()

# %% [markdown]
# In both conditions unknown getting not subscribed is higher than other types getting subscribed.

# %%
sns.pairplot(df, hue = 'subscribed')
plt.show()

# %% [markdown]
#  The pairplot gives the pairwise relationbetween the features on the basis of target 'subscribed'.On the diagonal we can notice the distribution of plots.

# %%
plt.figure(figsize=(20,15))
plotnumber=1

for col in numerical_col:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[col])
        plt.xlabel(col,fontsize=15)
    plotnumber+=1
plt.show()

# %% [markdown]
# In above boxplot except day all columns are having outliers.

# %% [markdown]
# ## Checking Skewness

# %%
df.skew()
# Out:
# age          0.681607
# balance      7.995696
# day          0.087185
# duration     3.199766
# campaign     4.873935
# pdays        2.642374
# previous    49.302348
# dtype: float64

# %%
df['previous'] = np.cbrt(df['previous'])

# %%
df.skew()
# Out:
# age         0.681607
# balance     7.995696
# day         0.087185
# duration    3.199766
# campaign    4.873935
# pdays       2.642374
# previous    2.079738
# dtype: float64

# %%
df['balance'] = np.cbrt(df['balance'])
df['duration'] = np.cbrt(df['duration'])
df['campaign'] = np.cbrt(df['campaign'])
df['pdays'] = np.cbrt(df['pdays'])

# %%
df.skew()
# Out:
# age         0.681607
# balance    -0.086014
# day         0.087185
# duration    0.647275
# campaign    1.667938
# pdays       1.779036
# previous    2.079738
# dtype: float64

# %% [markdown]
# After removing skewness,still having skewness in campaign,pdays,previous columns.

# %%
plt.figure(figsize=(25,15), facecolor='white')
plotnumber=1
for col in numerical_col:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[col], color='r')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# The data looks normal in all columns except campaign,pdays,previous.

# %% [markdown]
# ## Encoding Categorical Columns

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#        age   job  marital  education  default    balance  housing  loan  \
# 0       56   0.0      1.0        3.0      0.0  12.456918      0.0   0.0
# 1       31  11.0      1.0        1.0      0.0   1.442250      0.0   0.0
# 2       27   7.0      1.0        1.0      0.0   9.622603      1.0   0.0
# 3       57   4.0      0.0        2.0      0.0  14.868480      0.0   0.0
# 4       31   9.0      1.0        1.0      0.0   4.918685      1.0   0.0
# ...    ...   ...      ...        ...      ...        ...      ...   ...
# 31642   29   4.0      2.0        2.0      0.0   0.000000      1.0   0.0
# 31643   53   4.0      0.0        2.0      0.0   7.243156      0.0   1.0
# 31644   32   4.0      2.0        2.0      0.0   6.782423      0.0   0.0
# 31645   57   9.0      1.0        1.0      0.0   6.082202      1.0   0.0
# 31646   55   4.0      0.0        1.0      0.0   5.886765      1.0   0.0
#
#        contact  day  month   duration  campaign     pdays  previous  poutcome  \
# ...

# %%
from scipy.stats import zscore

z=np.abs(zscore(df[['age','balance','duration','campaign','pdays','previous']]))
z
# Out:
#             age   balance  duration  campaign     pdays  previous
# 0      1.415793  0.757778  1.328474  0.127816  0.461627  0.449105
# 1      0.937156  0.911548  0.775734  0.127816  0.461627  0.449105
# 2      1.313627  0.328224  0.204835  0.873593  0.461627  0.449105
# 3      1.509911  1.123262  2.101938  0.873593  1.542654  2.189741
# 4      0.937156  0.384677  0.792477  0.873593  0.461627  0.449105
# ...         ...       ...       ...       ...       ...       ...
# 31642  1.125392  1.130128  0.559197  0.127816  0.461627  0.449105
# 31643  1.133439  0.032392  0.993105  0.127816  0.461627  0.449105
# 31644  0.843038  0.102219  1.441655  0.395329  0.461627  0.449105
# 31645  1.509911  0.208341  1.744523  1.745828  2.503686  3.739801
# 31646  1.321675  0.237960  3.819603  0.127816  0.461627  0.449105
#
# [31647 rows x 6 columns]

# %%
np.where(z>3)
# Out:
# (array([   21,   109,   134, ..., 31622, 31645, 31646], dtype=int64),
#  array([3, 1, 3, ..., 0, 5, 2], dtype=int64))

# %%
df1 = df[(z<3).all(axis=1)]
df1.shape
# Out:
# (29842, 17)

# %%
print('OLd Data Frame- ',df.shape[0])
print('New Data Frame- ',df1.shape[0])
# Out:
# OLd Data Frame-  31647
# New Data Frame-  29842

# %%
print('Data Loss Percentage- ',((df.shape[0] - df1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage-  5.703542199892564

# %%
df=df1

# %%
plt.figure(figsize=(20,15),facecolor='green')
plotnumber=1

for column in df:
    if plotnumber<=17:
        ax=plt.subplot(5,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29842 entries, 0 to 31644
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         29842 non-null  int64
#  1   job         29842 non-null  float64
#  2   marital     29842 non-null  float64
#  3   education   29842 non-null  float64
#  4   default     29842 non-null  float64
#  5   balance     29842 non-null  float64
#  6   housing     29842 non-null  float64
#  7   loan        29842 non-null  float64
#  8   contact     29842 non-null  float64
#  9   day         29842 non-null  int64
#  10  month       29842 non-null  float64
#  11  duration    29842 non-null  float64
#  12  campaign    29842 non-null  float64
#  13  pdays       29842 non-null  float64
#  14  previous    29842 non-null  float64
#  15  poutcome    29842 non-null  float64
#  16  subscribed  29842 non-null  float64
# dtypes: float64(15), int64(2)
# memory usage: 4.1 MB

# %% [markdown]
# Now all object datatype has converted into float data type

# %%
df.describe()
# Out:
#                 age           job       marital     education       default  \
# count  29842.000000  29842.000000  29842.000000  29842.000000  29842.000000
# mean      40.604350      4.320991      1.170498      1.224214      0.018330
# std       10.069035      3.285476      0.607100      0.745051      0.134144
# min       18.000000      0.000000      0.000000      0.000000      0.000000
# 25%       33.000000      1.000000      1.000000      1.000000      0.000000
# 50%       39.000000      4.000000      1.000000      1.000000      0.000000
# 75%       48.000000      7.000000      2.000000      2.000000      0.000000
# max       72.000000     11.000000      2.000000      3.000000      1.000000
#
#             balance       housing          loan       contact           day  \
# count  29842.000000  29842.000000  29842.000000  29842.000000  29842.000000
# mean       7.336890      0.560083      0.163796      0.650962     15.745694
# ...

# %% [markdown]
# We have removed outliers , difference between 75% and max in age,balance,duration,campaign,pdays,previous is reduced to normal.

# %%
df.corr()
# Out:
#                  age       job   marital  education   default   balance  \
# age         1.000000 -0.028041 -0.411566  -0.096521 -0.011898  0.085006
# job        -0.028041  1.000000  0.067435   0.171279 -0.007116  0.029549
# marital    -0.411566  0.067435  1.000000   0.108255 -0.011218  0.035106
# education  -0.096521  0.171279  0.108255   1.000000 -0.008599  0.075433
# default    -0.011898 -0.007116 -0.011218  -0.008599  1.000000 -0.198678
# balance     0.085006  0.029549  0.035106   0.075433 -0.198678  1.000000
# housing    -0.160015 -0.124439 -0.023542  -0.101622 -0.013772 -0.078516
# loan        0.002113 -0.036902 -0.043908  -0.046784  0.079247 -0.140428
# contact     0.033857 -0.077381 -0.043544  -0.114509  0.014329 -0.049720
# day        -0.007881  0.020288 -0.007960   0.018589  0.006709 -0.007919
# month      -0.044846 -0.090949 -0.002782  -0.055116  0.005614 -0.002776
# duration   -0.025619 -0.004508  0.013794   0.005322 -0.004655  0.029694
# ...

# %%
df_corr = df.corr().abs()
plt.figure(figsize=(14,8))
sns.heatmap(df_corr,annot=True,annot_kws={'size':10})
# Out:
# <AxesSubplot:>

# %% [markdown]
# pdays has high correlation with previous=0.96,  pdays and poutcome=0.94 , previous and poutcome=0.92

# %%
plt.figure(figsize=(25,10))
df.corr()['subscribed'].sort_values(ascending=False).drop(['subscribed']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title("Correlation between Target and features using barplot",fontsize=25)
plt.show()

# %% [markdown]
# Age,default ,day has very less correlation with target column.

# %% [markdown]
# ## Separate feature and label

# %%
x = df.drop('subscribed',axis=1)
y = df['subscribed']

print('Features Dimension = ', x.shape)
print('Label Dimension = ', y.shape)
# Out:
# Features Dimension =  (29842, 16)
# Label Dimension =  (29842,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#             age       job   marital  education   default   balance   housing  \
# 0      1.529035 -1.315202 -0.280845   2.383481 -0.136646  0.797963 -1.128342
# 1     -0.953866  2.032924 -0.280845  -0.300943 -0.136646 -0.918688 -1.128342
# 2     -1.351130  0.815424 -0.280845  -0.300943 -0.136646  0.356231  0.886256
# 3      1.628351 -0.097702 -1.928048   1.041269 -0.136646  1.173808 -1.128342
# 4     -0.953866  1.424174 -0.280845  -0.300943 -0.136646 -0.376881  0.886256
# ...         ...       ...       ...        ...       ...       ...       ...
# 29837  0.237927 -0.097702  1.366358  -0.300943 -0.136646  1.096281 -1.128342
# 29838 -0.357970  1.424174  1.366358   1.041269 -0.136646  0.561403 -1.128342
# 29839 -1.152498 -0.097702  1.366358   1.041269 -0.136646 -1.143464  0.886256
# 29840  1.231087 -0.097702 -1.928048   1.041269 -0.136646 -0.014609 -1.128342
# 29841 -0.854550 -0.097702  1.366358   1.041269 -0.136646 -0.086414 -1.128342
#
# ...

# %% [markdown]
# ## VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i)
                    for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values   Features
# 0     1.274689        age
# 1     1.050456        job
# 2     1.230758    marital
# 3     1.067425  education
# 4     1.045909    default
# 5     1.087123    balance
# 6     1.186577    housing
# 7     1.030091       loan
# 8     1.332831    contact
# 9     1.027766        day
# 10    1.266370      month
# 11    1.014813   duration
# 12    1.056653   campaign
# 13   17.640019      pdays
# 14   12.617364   previous
# 15    9.172953   poutcome

# %% [markdown]
# By checking vif, we can say that vif values is more than 10 in pdays and previous columns which means high collinearity with other features
# We will drop first pdays column and check vif values.

# %%
x.drop('pdays',axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i)
                    for i in range(len(x.columns))]

vif['Features'] = x.columns
vif
# Out:
#     VIF values   Features
# 0     1.274301        age
# 1     1.050092        job
# 2     1.230745    marital
# 3     1.067028  education
# 4     1.045906    default
# 5     1.086920    balance
# 6     1.182269    housing
# 7     1.029517       loan
# 8     1.329963    contact
# 9     1.027020        day
# 10    1.266214      month
# 11    1.014430   duration
# 12    1.056490   campaign
# 13    6.435734   previous
# 14    6.443267   poutcome

# %% [markdown]
# We have solved multicollinearity issue.Now data looks normal.

# %%
y.value_counts()
# Out:
# 0.0    26552
# 1.0     3290
# Name: subscribed, dtype: int64

# %% [markdown]
# ## OverSampling

# %%
from imblearn.over_sampling import SMOTE

# %%
SM = SMOTE()
x,y = SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0.0    26552
# 1.0    26552
# Name: subscribed, dtype: int64

# %% [markdown]
# Now,data is imbalanced we can go for machine learnig classification models.

# %% [markdown]
# ## Train-Test-Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=430)

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.947903590258599
# [[7514  543]
#  [ 287 7588]]
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.95      8057
#          1.0       0.93      0.96      0.95      7875
#
#     accuracy                           0.95     15932
#    macro avg       0.95      0.95      0.95     15932
# weighted avg       0.95      0.95      0.95     15932

# %%
LR =LogisticRegression()
LR.fit(x_train,y_train)
predLR= LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.818353000251067
# [[6571 1486]
#  [1408 6467]]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.82      0.82      8057
#          1.0       0.81      0.82      0.82      7875
#
#     accuracy                           0.82     15932
#    macro avg       0.82      0.82      0.82     15932
# weighted avg       0.82      0.82      0.82     15932

# %%
svc = SVC()
svc.fit(x_train,y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8701355761988451
# [[6660 1397]
#  [ 672 7203]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.83      0.87      8057
#          1.0       0.84      0.91      0.87      7875
#
#     accuracy                           0.87     15932
#    macro avg       0.87      0.87      0.87     15932
# weighted avg       0.87      0.87      0.87     15932

# %%
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB = GB.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.9111222696459955
# [[7180  877]
#  [ 539 7336]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.89      0.91      8057
#          1.0       0.89      0.93      0.91      7875
#
#     accuracy                           0.91     15932
#    macro avg       0.91      0.91      0.91     15932
# weighted avg       0.91      0.91      0.91     15932

# %%
ABC = AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC = ABC.predict(x_test)
print(accuracy_score(y_test,predABC))
print(confusion_matrix(y_test,predABC))
print(classification_report(y_test,predABC))
# Out:
# 0.8739015817223199
# [[7063  994]
#  [1015 6860]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.88      0.88      8057
#          1.0       0.87      0.87      0.87      7875
#
#     accuracy                           0.87     15932
#    macro avg       0.87      0.87      0.87     15932
# weighted avg       0.87      0.87      0.87     15932

# %%
BC = BaggingClassifier()
BC.fit(x_train,y_train)
predBC = BC.predict(x_test)
print(accuracy_score(y_test,predBC))
print(confusion_matrix(y_test,predBC))
print(classification_report(y_test,predBC))
# Out:
# 0.9287597288476023
# [[7453  604]
#  [ 531 7344]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93      8057
#          1.0       0.92      0.93      0.93      7875
#
#     accuracy                           0.93     15932
#    macro avg       0.93      0.93      0.93     15932
# weighted avg       0.93      0.93      0.93     15932

# %%
ET = ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET = ET.predict(x_test)
print(accuracy_score(y_test,predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.960456942003515
# [[7561  496]
#  [ 134 7741]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.94      0.96      8057
#          1.0       0.94      0.98      0.96      7875
#
#     accuracy                           0.96     15932
#    macro avg       0.96      0.96      0.96     15932
# weighted avg       0.96      0.96      0.96     15932

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT = DecisionTreeClassifier()
DT.fit(x_train,y_train)
predDT = DT.predict(x_test)
print(accuracy_score(y_test,predDT))
print(confusion_matrix(y_test,predDT))
print(classification_report(y_test,predDT))
# Out:
# 0.9037157921164951
# [[7214  843]
#  [ 691 7184]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.90      0.90      8057
#          1.0       0.89      0.91      0.90      7875
#
#     accuracy                           0.90     15932
#    macro avg       0.90      0.90      0.90     15932
# weighted avg       0.90      0.90      0.90     15932

# %% [markdown]
# ## Cross ValidationScore

# %%
score1=cross_val_score(RFC,x,y)
print(score1)
print(score1.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predRFC) - score1.mean())
# Out:
# [0.90443461 0.96102062 0.96233876 0.96215046 0.96054614]
# 0.9500981178069742
# Difference between Accuracy score and cross validation score is -  -0.0021945275483751248

# %%
score2=cross_val_score(LR,x,y)
print(score2)
print(score2.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predLR) - score2.mean())
# Out:
# [0.81075228 0.81790792 0.82167404 0.82365126 0.82259887]
# 0.8193168740960373
# Difference between Accuracy score and cross validation score is -  -0.0009638738449702089

# %%
score3=cross_val_score(GB,x,y)
print(score3)
print(score3.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predGB) - score3.mean())
# Out:
# [0.8446474  0.91987572 0.92458337 0.92561906 0.92052731]
# 0.9070505701404195
# Difference between Accuracy score and cross validation score is -  0.004071699505576065

# %%
score4=cross_val_score(svc,x,y)
print(score4)
print(score4.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predsvc) - score4.mean())
# Out:
# [0.86027681 0.87458808 0.87694191 0.87552961 0.87730697]
# 0.8729286753971939
# Difference between Accuracy score and cross validation score is -  -0.002793099198348803

# %%
score5=cross_val_score(ABC,x,y)
print(score5)
print(score5.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predABC) - score5.mean())
# Out:
# [0.82139158 0.88965258 0.89549007 0.89115902 0.88907721]
# 0.8773540924058526
# Difference between Accuracy score and cross validation score is -  -0.0034525106835326946

# %%
score6=cross_val_score(BC,x,y)
print(score6)
print(score6.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predBC) - score6.mean())
# Out:
# [0.86790321 0.94793334 0.94595612 0.9498164  0.95122411]
# 0.9325666363639105
# Difference between Accuracy score and cross validation score is -  -0.003806907516308189

# %%
score7=cross_val_score(ET,x,y)
print(score7)
print(score7.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predET) - score7.mean())
# Out:
# [0.95631296 0.96883533 0.96827041 0.96836456 0.96685499]
# 0.9657276500327763
# Difference between Accuracy score and cross validation score is -  -0.005270708029261328

# %%
score8=cross_val_score(DT,x,y)
print(score8)
print(score8.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predDT) - score8.mean())
# Out:
# [0.8494492  0.92006402 0.92674889 0.92627813 0.92824859]
# 0.9101577676035696
# Difference between Accuracy score and cross validation score is -  -0.0064419754870744805

# %% [markdown]
# Decision Tree Classifier is the best as difference betweeen accuracy score and cross validation score is least.
#
# Decision Tree Classifier is the best model.

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'criterion':['gini','entropy'],
            'max_depth':[0,10,20],
            'min_samples_leaf':[5,10,15],
            'min_samples_split':[3,6,9],
            'random_state':[10,50,100]}

# %%
GCV=GridSearchCV(DecisionTreeClassifier(),parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'min_samples_leaf': [5, 10, 15],
#                          'min_samples_split': [3, 6, 9],
#                          'random_state': [10, 50, 100]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'min_samples_leaf': 5,
#  'min_samples_split': 3,
#  'random_state': 100}

# %%
Final_model = DecisionTreeClassifier(criterion='entropy',max_depth=20,min_samples_leaf=5,min_samples_split=3,random_state=100)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
acc = accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 89.95731860406728

# %% [markdown]
# The accuracy for Final model for DecisionTreeClassifier is 90%.

# %%
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import plot_roc_curve

# %%
dis = plot_roc_curve(DT,x_test,y_test)
plot_roc_curve(LR,x_test,y_test,ax=dis.ax_)
plot_roc_curve(RFC,x_test,y_test,ax=dis.ax_)
plot_roc_curve(GB,x_test,y_test,ax=dis.ax_)
plot_roc_curve(ABC,x_test,y_test,ax=dis.ax_)
plot_roc_curve(svc,x_test,y_test,ax=dis.ax_)
plot_roc_curve(BC,x_test,y_test,ax=dis.ax_)
plot_roc_curve(ET,x_test,y_test,ax=dis.ax_)

plt.legend(prop={'size':10}, loc='lower right')
plt.show()

# %% [markdown]
# This is ROC_curve plot for all models for test data which shows accuracy for all models.

# %%
dis = plot_roc_curve(DT,x_train,y_train)
plot_roc_curve(LR,x_train,y_train,ax=dis.ax_)
plot_roc_curve(RFC,x_train,y_train,ax=dis.ax_)
plot_roc_curve(GB,x_train,y_train,ax=dis.ax_)
plot_roc_curve(ABC,x_train,y_train,ax=dis.ax_)
plot_roc_curve(svc,x_train,y_train,ax=dis.ax_)
plot_roc_curve(BC,x_train,y_train,ax=dis.ax_)
plot_roc_curve(ET,x_train,y_train,ax=dis.ax_)

plt.legend(prop={'size':10}, loc='lower right')
plt.show()

# %% [markdown]
# This is ROC_curve plot for all models for train data which shows accuracy for all models.

# %% [markdown]
# ## SAving model

# %%
import joblib
import pickle

# %%
pickle.dump(Final_model,open('Bank_Marketing.pkl', 'wb'))

# %%
loaded_model = pickle.load(open('Bank_Marketing.pkl', 'rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 89.95731860406728

# %% [markdown]
# ## Predicting Saved Model

# %%
prediction =Final_model.predict(x_test)
prediction
# Out:
# array([1., 0., 0., ..., 0., 1., 0.])

# %% [markdown]
# This are the predicted value of customers those who will subscribe or not.
