# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\Administrator\Desktop\DSData-master\winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
df["quality"]= df['quality'].apply(lambda x: 1 if x>=6 else 0)

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# The dataset contains 1599 rows and 12 columns.Out of which 1 is target variable  and remaining 11 are independent variaables.

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# There are no null values present in the dataset

# %%
df['quality'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['quality'].nunique()
# Out:
# 2

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
#
#
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
#
#
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
#
#
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64
#
#
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# ...

# %% [markdown]
# We can see except 'quality' all are continous data present.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see there is no misssing values present.

# %%
df.nunique().to_frame('No. of unique values')
# Out:
#                       No. of unique values
# fixed acidity                           96
# volatile acidity                       143
# citric acid                             80
# residual sugar                          91
# chlorides                              153
# free sulfur dioxide                     60
# total sulfur dioxide                   144
# density                                436
# pH                                      89
# sulphates                               96
# alcohol                                 65
# quality                                  2

# %% [markdown]
# Since,Target column has 2 unique values present ,it is a Classification problem.

# %% [markdown]
# # Description of Dataset

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# 1) The count of all columns are same means there are no missing values present.
#
# 2) The mean value is greater than meadian(50%) in columns 'fixed Acidity','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','sulphates','alcohol' which means data is skewed to right.
#
# 3) The columns in which mean is equal to median which means data is normaly distributed in this columns-'volatile acidity','citric acid','density','pH'.
#
# 4) There are maximum difference between 75% and max in 'fixed acidity','residual sugar','free sulfur dioxide','total sulfur dioxide','sulphates','alcohol' ,since there are outliers present in those columns.

# %%
plt.figure(figsize=(20,25))
plotnumber=1

for column in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# From the Distplot graph we can say that 'fixed acidity','volatile acidity,''citric acid','density','pH' looks normal in all this columns and do not have skewness.
#
# And 'residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','sulphates' and 'alcohol' is skewed to right.

# %%
sns.scatterplot(x='fixed acidity',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(x='volatile acidity',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
sns.scatterplot(x='citric acid',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
sns.scatterplot(x='residual sugar',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
sns.scatterplot(x='chlorides',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x='density',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
sns.scatterplot(x='pH',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
sns.scatterplot(x='sulphates',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
sns.scatterplot(x='alcohol',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
sns.pairplot(df,hue='quality')
plt.show()

# %% [markdown]
# 1) The pairplot gives the pairwise relationbetween the features on the basis of target 'quality'.On the diagonal we can notice the distribution of plots.

# %%
plt.figure(figsize=(25,10), facecolor = 'white')
plotnumber=1
for col in df:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(df[col], palette='Set2_r')
        plt.xlabel(col,fontsize=15)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.show()

# %%
from scipy.stats import zscore

z=np.abs(zscore(df))
z.shape
# Out:
# (1599, 12)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#         244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#         354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#         467,  480,  480,  494,  515,  544,  554,  554,  555,  555,  557,
#         557,  568,  584,  588,  591,  595,  608,  614,  636,  639,  649,
#         649,  651,  652,  652,  652,  672,  672,  684,  690,  692,  692,
#         695,  723,  724,  730,  754,  776,  777,  795,  821,  836,  837,
#         889,  911,  917,  923,  925,  926,  982, 1017, 1018, 1043, 1051,
#        1051, 1071, 1074, 1079, 1079, 1081, 1081, 1111, 1114, 1131, 1154,
#        1165, 1175, 1186, 1231, 1235, 1244, 1244, 1244, 1260, 1269, 1269,
# ...

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df1.shape
# Out:
# (1458, 12)

# %%
print('OLd Data Frame- ',df.shape[0])
print('New Data Frame- ',df1.shape[0])
# Out:
# OLd Data Frame-  1599
# New Data Frame-  1458

# %%
print('Data Loss Percentage- ',((df.shape[0] - df1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage-  8.818011257035648

# %%
df=df1

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1458.000000       1458.000000  1458.000000     1458.000000
# mean        8.312551          0.524050     0.265281        2.388717
# std         1.647635          0.169451     0.191271        0.865307
# min         5.000000          0.120000     0.000000        1.200000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.200000          0.635000     0.420000        2.600000
# max        13.500000          1.040000     0.790000        6.700000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1458.000000          1458.000000           1458.000000  1458.000000
# mean      0.081531            15.089849             43.660494     0.996718
# std       0.021218             9.317669             29.414615     0.001718
# ...

# %%
plt.figure(figsize=(20,25))
plotnumber=1

for column in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above distribution plots we can say data looks normal in all the columns except 'residual sugar','chlorides','total sulfur dioxide','free sulfur dioxise'

# %%
df.skew()
# Out:
# fixed acidity           0.820879
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          2.450707
# chlorides               2.307274
# free sulfur dioxide     0.869727
# total sulfur dioxide    1.185230
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# quality                -0.159793
# dtype: float64

# %%
df['fixed acidity'] = np.cbrt(df['fixed acidity'])

# %%
df.skew()
# Out:
# fixed acidity           0.527560
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          2.450707
# chlorides               2.307274
# free sulfur dioxide     0.869727
# total sulfur dioxide    1.185230
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# quality                -0.159793
# dtype: float64

# %%
df['residual sugar'] = np.cbrt(df['residual sugar'])
df['chlorides'] = np.cbrt(df['chlorides'])
df['free sulfur dioxide'] = np.cbrt(df['free sulfur dioxide'])
df['total sulfur dioxide'] = np.cbrt(df['total sulfur dioxide'])
df['sulphates'] = np.cbrt(df['sulphates'])
df['alcohol'] = np.cbrt(df['alcohol'])

# %%
df.skew()
# Out:
# fixed acidity           0.527560
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          1.629756
# chlorides               1.056128
# free sulfur dioxide     0.127793
# total sulfur dioxide    0.343010
# density                 0.055543
# pH                      0.113039
# sulphates               0.526494
# alcohol                 0.643830
# quality                -0.159793
# dtype: float64

# %% [markdown]
# We have remove skewness in 'fixed acidity','free sulfur dioxide','total sulfur dioxide','sulphates','alcohol' and after removing skewness we have skewness in 'residual sugar','chlorides'

# %%
plt.figure(figsize=(20,25),facecolor='red')
plotnumber=1

for column in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# ## Correlation with Target and Independent variable

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.296687     0.696169
# volatile acidity          -0.296687          1.000000    -0.589286
# citric acid                0.696169         -0.589286     1.000000
# residual sugar             0.196737          0.035657     0.186738
# chlorides                  0.218480          0.077700     0.105771
# free sulfur dioxide       -0.165764          0.032589    -0.097483
# total sulfur dioxide      -0.098864          0.102031    -0.015382
# density                    0.663596         -0.000446     0.372338
# pH                        -0.716596          0.252900    -0.521270
# sulphates                  0.195504         -0.355067     0.307518
# alcohol                   -0.031849         -0.212976     0.163903
# quality                    0.109366         -0.297348     0.169947
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df_corr = df.corr().abs()
plt.figure(figsize=(14,8))
sns.heatmap(df_corr,annot=True,annot_kws={'size':10})
# Out:
# <AxesSubplot:>

# %% [markdown]
# It seems 'free sulfur dioxide' and 'total sulfur dioxide' are  correlated as per above heatmap .

# %%
plt.figure(figsize=(25,10))
df.corr()['quality'].sort_values(ascending=False).drop(['quality']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title("Correlation between Target and features using barplot",fontsize=25)
plt.show()

# %% [markdown]
# From the above plot,we can see 'residual sugar' has very less correlation with Target column.So,by checking skewness,distplot and heatmap and barplot we can see 'residual sugar' is very less contributing to target column.

# %% [markdown]
# ## Separate feature and label

# %%
x=df.drop(columns=['quality','residual sugar'])
y=df['quality']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()
x_scaled=scalar.fit_transform(x)

# %%
x_scaled.shape[1]
# Out:
# 10

# %% [markdown]
# ### Checking VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]

vif['Features'] = x.columns
vif
# Out:
#         vif              Features
# 0  7.026552         fixed acidity
# 1  1.853430      volatile acidity
# 2  3.126271           citric acid
# 3  1.212476             chlorides
# 4  2.576060   free sulfur dioxide
# 5  2.849797  total sulfur dioxide
# 6  4.567725               density
# 7  3.097135                    pH
# 8  1.313144             sulphates
# 9  2.270096               alcohol

# %% [markdown]
# By checking VIF values we can find the features causing multicollinearity problem.VIF value greater than 10 which means they have high correlation with other features.All features are less than 10 means multicollinearity doesnot exists in all this features.All are independent.So,we dont have multicollinearity problem arises,which means all the features are important.

# %%
y.value_counts()
# Out:
# 1    787
# 0    671
# Name: quality, dtype: int64

# %% [markdown]
# Since the data is imbalanced.Now we can go for Model Building

# %%
# Finding the best random state

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu = 0
maxRS = 0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    RFR = RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred = RFR.predict(x_test)
    acc = accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS =i
print('Best accuracy is ', maxAccu,"at random_state",maxRS)
# Out:
# Best accuracy is  0.8470319634703196 at random_state 11

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.8242009132420092
# [[169  36]
#  [ 41 192]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81       205
#            1       0.84      0.82      0.83       233
#
#     accuracy                           0.82       438
#    macro avg       0.82      0.82      0.82       438
# weighted avg       0.82      0.82      0.82       438

# %%
LR =LogisticRegression()
LR.fit(x_train,y_train)
predLR= LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.7557077625570776
# [[132  73]
#  [ 34 199]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.64      0.71       205
#            1       0.73      0.85      0.79       233
#
#     accuracy                           0.76       438
#    macro avg       0.76      0.75      0.75       438
# weighted avg       0.76      0.76      0.75       438

# %%
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB = GB.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.817351598173516
# [[161  44]
#  [ 36 197]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.80       205
#            1       0.82      0.85      0.83       233
#
#     accuracy                           0.82       438
#    macro avg       0.82      0.82      0.82       438
# weighted avg       0.82      0.82      0.82       438

# %%
ABC = AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC = ABC.predict(x_test)
print(accuracy_score(y_test,predABC))
print(confusion_matrix(y_test,predABC))
print(classification_report(y_test,predABC))
# Out:
# 0.7625570776255708
# [[145  60]
#  [ 44 189]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74       205
#            1       0.76      0.81      0.78       233
#
#     accuracy                           0.76       438
#    macro avg       0.76      0.76      0.76       438
# weighted avg       0.76      0.76      0.76       438

# %%
svc = SVC()
svc.fit(x_train,y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.7009132420091324
# [[110  95]
#  [ 36 197]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.54      0.63       205
#            1       0.67      0.85      0.75       233
#
#     accuracy                           0.70       438
#    macro avg       0.71      0.69      0.69       438
# weighted avg       0.71      0.70      0.69       438

# %%
BC = BaggingClassifier()
BC.fit(x_train,y_train)
predBC = BC.predict(x_test)
print(accuracy_score(y_test,predBC))
print(confusion_matrix(y_test,predBC))
print(classification_report(y_test,predBC))
# Out:
# 0.8127853881278538
# [[166  39]
#  [ 43 190]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       205
#            1       0.83      0.82      0.82       233
#
#     accuracy                           0.81       438
#    macro avg       0.81      0.81      0.81       438
# weighted avg       0.81      0.81      0.81       438

# %%
ET = ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET = ET.predict(x_test)
print(accuracy_score(y_test,predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.815068493150685
# [[162  43]
#  [ 38 195]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       205
#            1       0.82      0.84      0.83       233
#
#     accuracy                           0.82       438
#    macro avg       0.81      0.81      0.81       438
# weighted avg       0.81      0.82      0.81       438

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(x_train,y_train)
predDT = DT.predict(x_test)
print(accuracy_score(y_test,predDT))
print(confusion_matrix(y_test,predDT))
print(classification_report(y_test,predDT))
# Out:
# 0.7579908675799086
# [[145  60]
#  [ 46 187]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73       205
#            1       0.76      0.80      0.78       233
#
#     accuracy                           0.76       438
#    macro avg       0.76      0.75      0.76       438
# weighted avg       0.76      0.76      0.76       438

# %% [markdown]
# # CrossValidationScore

# %%
from sklearn.model_selection import cross_val_score

# %%
score1=cross_val_score(RFC,x,y)
print(score1)
print(score1.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predRFC) - score1.mean())
# Out:
# [0.6609589  0.7260274  0.76369863 0.71821306 0.69415808]
# 0.7126112131054937
# Difference between Accuracy score and cross validation score is -  0.11158970013651548

# %%
score2=cross_val_score(LR,x,y)
print(score2)
print(score2.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predLR) - score2.mean())
# Out:
# [0.71917808 0.71232877 0.79109589 0.73195876 0.70446735]
# 0.7318057713129031
# Difference between Accuracy score and cross validation score is -  0.02390199124417447

# %%
score3=cross_val_score(GB,x,y)
print(score3)
print(score3.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predGB) - score3.mean())
# Out:
# [0.69520548 0.69520548 0.73972603 0.71821306 0.75257732]
# 0.7201854728616486
# Difference between Accuracy score and cross validation score is -  0.09716612531186741

# %%
score4=cross_val_score(svc,x,y)
print(score4)
print(score4.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predGB) - score4.mean())
# Out:
# [0.74315068 0.66780822 0.7260274  0.67353952 0.65635739]
# 0.6933766417172715
# Difference between Accuracy score and cross validation score is -  0.12397495645624446

# %%
score5=cross_val_score(ABC,x,y)
print(score5)
print(score5.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predABC) - score5.mean())
# Out:
# [0.68835616 0.70890411 0.75684932 0.73539519 0.71821306]
# 0.7215435672927553
# Difference between Accuracy score and cross validation score is -  0.04101351033281553

# %%
score6=cross_val_score(BC,x,y)
print(score6)
print(score6.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predBC) - score6.mean())
# Out:
# [0.60616438 0.70547945 0.76712329 0.68728522 0.67353952]
# 0.6879183731111425
# Difference between Accuracy score and cross validation score is -  0.12486701501671138

# %%
score7=cross_val_score(ET,x,y)
print(score7)
print(score7.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predET) - score7.mean())
# Out:
# [0.66438356 0.69863014 0.75       0.71134021 0.71477663]
# 0.707826107423622
# Difference between Accuracy score and cross validation score is -  0.10724238572706302

# %%
score8=cross_val_score(DT,x,y)
print(score8)
print(score8.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predDT) - score8.mean())
# Out:
# [0.57876712 0.69863014 0.67465753 0.66323024 0.61168385]
# 0.6453937767735254
# Difference between Accuracy score and cross validation score is -  0.11259709080638325

# %% [markdown]
# Least differecnce between accuracy score and cross validation score is for LogisticRegression is our best fiiting and best performing model.

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'fit_intercept':[True,False],
        'solver':['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
        'n_jobs':[-2,-1,1],
        'random_state':[10,50,100]}

# %%
GCV=GridSearchCV(LogisticRegression(),parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'fit_intercept': [True, False], 'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 100],
#                          'solver': ['lbfgs', 'liblinear', 'newton-cg',
#                                     'newton-cholesky', 'sag', 'saga']})

# %%
GCV.best_params_
# Out:
# {'fit_intercept': True, 'n_jobs': -2, 'random_state': 10, 'solver': 'lbfgs'}

# %%
Model=LogisticRegression( fit_intercept=True,n_jobs=-2,random_state=10,solver='lbfgs')
Model.fit(x_train,y_train)
pred = Model.predict(x_test)
acc = accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 75.57077625570776

# %%
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import plot_roc_curve

# %%
dis = plot_roc_curve(DT,x_test,y_test)
plot_roc_curve(LR,x_test,y_test,ax=dis.ax_)
plot_roc_curve(RFC,x_test,y_test,ax=dis.ax_)
plot_roc_curve(GB,x_test,y_test,ax=dis.ax_)
plot_roc_curve(ABC,x_test,y_test,ax=dis.ax_)
plot_roc_curve(svc,x_test,y_test,ax=dis.ax_)
plot_roc_curve(BC,x_test,y_test,ax=dis.ax_)
plot_roc_curve(ET,x_test,y_test,ax=dis.ax_)

plt.legend(prop={'size':10}, loc='lower right')
plt.show()

# %% [markdown]
# This is ROC_curve plot for all models for test data which shows accuracy for all models.

# %%
dis = plot_roc_curve(DT,x_train,y_train)
plot_roc_curve(LR,x_train,y_train,ax=dis.ax_)
plot_roc_curve(RFC,x_train,y_train,ax=dis.ax_)
plot_roc_curve(GB,x_train,y_train,ax=dis.ax_)
plot_roc_curve(ABC,x_train,y_train,ax=dis.ax_)
plot_roc_curve(svc,x_train,y_train,ax=dis.ax_)
plot_roc_curve(BC,x_train,y_train,ax=dis.ax_)
plot_roc_curve(ET,x_train,y_train,ax=dis.ax_)

plt.legend(prop={'size':10}, loc='lower right')
plt.show()

# %% [markdown]
# This is ROC_curve plot for all models for train data which shows accuracy for all models.
