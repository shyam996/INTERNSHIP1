# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\Administrator\Desktop\Data-Science-ML-Capstone-Projects-master\baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head(10)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5  93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6  87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7  81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8  80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9  78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86
# 5  34   88
# 6  48   93
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.nunique().to_frame("No. of unique values")
# Out:
#      No. of unique values
# W                      24
# R                      28
# AB                     29
# H                      29
# 2B                     22
# 3B                     23
# HR                     27
# BB                     29
# SO                     29
# SB                     27
# RA                     30
# ER                     30
# ERA                    30
# CG                      9
# SHO                    12
# SV                     20
# E                      21

# %% [markdown]
# W is a Target variable ,we can say that it is a Regression problem.

# %%
print('Total Duplicates Rows are ',df.duplicated().sum())
# Out:
# Total Duplicates Rows are  0

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# 1) The counts of all columns are same.
#
# 2) The mean > median(50%) in AB,H,HR,CG,SV,E Columns,which means data is skewed to right
#
# 3) The mean < median(50%) in R,2B,BB,SO,RA,ER,ERA,SHO Columns, which means data is skewed to left.
#
# 4) The mean = median(50%) in 3B,SB Columns, data is normally distributed.
#
# 5) THere is difference between 75% and max ,which means outliers is present.

# %%
plt.figure(figsize=(20,25))
plotnumber = 1

for column in df:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# By Distplot we can say that data looks normal in all the columns except few columns.

# %%
sns.lmplot(x='R',y='W',data=df)

# %% [markdown]
# Most of data are gathered in best fit line,so we can say W  has positive correlation with R.

# %%
sns.lmplot(x='AB',y='W',data=df)

# %% [markdown]
# AB does not have positive correlation with W ,because most of data are not in best fit line.

# %%
sns.lmplot(x='H',y='W',data=df)

sns.lmplot(x='2B',y='W',data=df)

# %% [markdown]
# 1) H does not have positive correlation with W and  most of data are not in best fit line.It has not positive relationship.
#
# 2) Most of data are gathered in best fit line,so we can say W  has positive correlation with 2B.

# %%
sns.lmplot(x='3B',y='W',data=df)
sns.lmplot(x='HR',y='W',data=df)
sns.lmplot(x='BB',y='W',data=df)
sns.lmplot(x='SO',y='W',data=df)

# %% [markdown]
# 1) 3B does not have positive correlation with W and  most of data are not in best fit line.It has not positive relationship.
#
# 2) Most of data are gathered in best fit line,so we can say W  has positive correlation with HR.
#
# 3) Most of data are gathered in best fit line,so we can say W  has positive correlation with BB.
#
# 4) SO does not have positive correlation with W and  most of data are not in best fit line.It has not positive relationship.

# %%
sns.lmplot(x='SB',y='W',data=df)
sns.lmplot(x='RA',y='W',data=df)
sns.lmplot(x='ER',y='W',data=df)

# %% [markdown]
# 1)SB does not have positive correlation with W and  most of data are not in best fit line.It has not positive relationship.
#
# 2) RA does not have positive correlation with W and  most of data are not in best fit line.It has not positive relationship.
#
# 3) ER does not have positive correlation with W and  most of data are not in best fit line.It has not positive relationship.

# %%
sns.lmplot(x='ERA',y='W',data=df)
sns.lmplot(x='CG',y='W',data=df)
sns.lmplot(x='SHO',y='W',data=df)

# %% [markdown]
# 1) ERA does not have positive correlation with W and  most of data are not in best fit line.It has not positive relationship.
#
# 2) CG does not have positive correlation with W and  most of data are not in best fit line.It has not positive relationship.
#
# 3) Most of data are gathered in best fit line,so we can say W  has positive correlation with SHO.

# %%
sns.lmplot(x='SV',y='W',data=df)
sns.lmplot(x='E',y='W',data=df)

# %% [markdown]
# 1) Most of data are gathered in best fit line,so we can say W  has positive correlation with SV.
#
# 2) E does not have positive correlation with W and  most of data are not in best fit line.It has not positive relationship.

# %%
plt.figure(figsize=(20,25))
plotnumber=1
for i in df:
    if plotnumber<=17:
        plt.subplot(6,3,plotnumber)
        sns.scatterplot(x='W',y=i,data=df,color='r')
        plt.xlabel('W')
        plt.ylabel(i)
    plotnumber+=1

plt.show()

# %%
sns.pairplot(data=df,palette = 'Dark2')

# %%
plt.figure(figsize=(20,25))
plotnumber=1

for col in df:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.boxplot(df[col])
        plt.xlabel(col,fontsize=15)
    plotnumber+=1
plt.show()

# %% [markdown]
# In above Boxplot, we can say that R,ERA,SHO,SV Columns has Outliers.Rest looks normal.

# %%
from scipy.stats import zscore
out_features=df[['R','ERA', 'SHO', 'SV']]
z=np.abs(zscore(out_features))
z
# Out:
#            R       ERA       SHO        SV
# 0   0.619078  0.506955  0.814629  1.671607
# 1   0.134432  0.254598  0.172800  0.249879
# 2   0.332906  0.641347  0.320914  0.654856
# 3   1.146419  0.053010  0.567771  0.784104
# 4   0.013270  1.531318  0.172800  1.042600
# 5   3.509647  0.350165  0.320914  1.171848
# 6   1.311430  0.165003  1.802057  0.637623
# 7   0.428681  0.209800  0.320914  0.008617
# 8   0.765626  0.484557  0.172800  2.188598
# 9   1.034489  0.792164  0.320914  0.396360
# 10  1.086415  0.635374  0.567771  0.249879
# 11  0.705622  0.865333  0.419657  0.525608
# 12  0.471376  0.036584  0.172800  0.379127
# 13  0.557920  0.456185  0.172800  0.249879
# 14  0.099814  0.411388  0.913371  1.947335
# 15  0.713699  2.276445  0.913371  2.447094
# 16  0.151740  1.671683  0.419657  1.413111
# 17  0.013270  1.335704  2.394514  0.637623
# 18  0.575229  0.724968  1.061486  0.396360
# 19  0.834861  0.836961  0.814629  1.042600
# 20  0.090583  1.178913  0.666514  0.896119
# ...

# %%
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
df_1 = df[(z<3).all(axis=1)]
df_1.shape
# Out:
# (29, 17)

# %%
print('OLd Data Frame- ',df.shape[0])
print('New Data Frame- ',df_1.shape[0])
# Out:
# OLd Data Frame-  30
# New Data Frame-  29

# %%
print('Data Loss Percentage- ',((df.shape[0] - df_1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage-  3.3333333333333335

# %%
df = df_1

# %%
plt.figure(figsize=(20,25),facecolor='green')
plotnumber=1

for column in df:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# Here above plot we can say that data looks normal in almost all columns.

# %% [markdown]
# ## Checking Skewness

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# We have skewnes in H,CG,E Columns.

# %%
df['H'] = np.cbrt(df['H'])
df['CG'] = np.cbrt(df['CG'])
df['E'] = np.cbrt(df['E'])

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.753696
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -1.013981
# SHO    0.526943
# SV     0.627480
# E      0.671748
# dtype: float64

# %% [markdown]
# After removing skewness We remove skewness in E column but still have skewness in H and CG column.

# %%
plt.figure(figsize=(20,25),facecolor='red')
plotnumber=1

for column in df:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
#  By above plot we can say that now data looks normal.

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.019968  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.432686  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.769847  0.490752  0.445604 -0.064653
# H   -0.019968  0.432686  0.769847  1.000000  0.527588  0.580521 -0.219048
# 2B   0.384886  0.469293  0.490752  0.527588  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.580521  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.219048 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.221951  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.372834 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.419443  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.243965 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.280165 -0.224993  0.333731 -0.062094
# ...

# %%
df_corr = df.corr().abs()
plt.figure(figsize=(25,20))
sns.heatmap(df_corr,annot=True,annot_kws={'size':10})
# Out:
# <AxesSubplot:>

# %% [markdown]
# RA has high collinearity with ER=0.99 and ERA=0.99 , ER Has high coolinearity with target W column i.e, 0.82 and ERA has high collinearity with Target column W i.e,0.83.
# So, according with Target variable ERA has high value than ER and it is less  ,so we can drop ER Column.

# %%
plt.figure(figsize=(25,10))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title("Correlation between Target and features using barplot",fontsize=25)
plt.show()

# %% [markdown]
# By above barplot,we can say that H,CG has very less contributing with Target variable.

# %% [markdown]
# So,we can say that H and CG after removing skewness it has skewness also,distplot is not looks normal and it has less contributing with Target Variable.

# %%
x = df.drop('W',axis=1)
y = df['W']

print('Features Dimension = ', x.shape)
print('Label Dimension = ', y.shape)
# Out:
# Features Dimension =  (29, 16)
# Label Dimension =  (29,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.728647  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.946162  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.094708  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.351839 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.041742  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.058116 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.555092 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.315000  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.693704  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.342114  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.685001  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.284608 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %% [markdown]
# ## Checking VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i)
                    for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#      VIF values Features
# 0      6.971450        R
# 1     15.981793       AB
# 2      8.812715        H
# 3      3.967135       2B
# 4      3.301273       3B
# 5      8.371778       HR
# 6      3.653286       BB
# 7      2.875697       SO
# 8      1.995051       SB
# 9    198.739986       RA
# 10  1716.427160       ER
# 11  1339.034481      ERA
# 12     2.780245       CG
# 13     3.670824      SHO
# 14     4.548702       SV
# 15     2.190238        E

# %% [markdown]
# By checking VIF values, we will drop ER column greter than 10 to solve multicollinearity issue.

# %%
x.drop('ER',axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i)
                    for i in range(len(x.columns))]

vif['Features'] = x.columns
vif
# Out:
#     VIF values Features
# 0     6.336177        R
# 1     7.186227       AB
# 2     8.543863        H
# 3     3.698105       2B
# 4     3.295620       3B
# 5     7.475528       HR
# 6     3.653104       BB
# 7     2.874505       SO
# 8     1.860509       SB
# 9   146.930689       RA
# 10  143.957732      ERA
# 11    2.550711       CG
# 12    3.540952      SHO
# 13    2.441365       SV
# 14    2.117066        E

# %% [markdown]
# Again to solve multicollinearity issue , we will drop ERA column

# %%
x.drop('ERA',axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i)
                    for i in range(len(x.columns))]

vif['Features'] = x.columns
vif
# Out:
#     VIF values Features
# 0     6.321097        R
# 1     4.615516       AB
# 2     6.966524        H
# 3     3.612997       2B
# 4     3.211506       3B
# 5     6.314607       HR
# 6     3.254677       BB
# 7     2.388554       SO
# 8     1.835004       SB
# 9     5.652363       RA
# 10    2.512606       CG
# 11    3.484908      SHO
# 12    2.407136       SV
# 13    2.078950        E

# %% [markdown]
#  Now data looks normal for VIF values of all columns.

# %% [markdown]
# By checking VIF values we can check multicollinearity problem. Hence all the features  VIF values are less than 10 , we can say that all those features are important,multicollinearity does not exists in this features,it means all those feaures are important.

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=25)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training Data : ', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :- ', mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error :- ', mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :- ', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: -2.096050718718666
# R2_score on training Data :  96.65179075133909
# Mean Absolute Error :-  11.17206715905467
# Mean Squared Error :-  161.98843143123096
# Root Mean Squared Error :-  12.72746759694288

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_RFR))
print('Root Mean Squared Error :- ', np.sqrt(mean_squared_error(y_test,pred_RFR)))
print('R2_score on training Data : ', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :- ', mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error :- ', mean_squared_error(y_test,pred_RFR))
# Out:
# R2_score: -0.10448539405379886
# Root Mean Squared Error :-  7.601826534897167
# R2_score on training Data :  92.49385344710822
# Mean Absolute Error :-  5.845555555555555
# Mean Squared Error :-  57.78776666666667

# %%
knn = KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on training Data : ', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :- ', mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error :- ', mean_squared_error(y_test,pred_knn))
print('Root Mean Squared Error :- ', np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score: -0.3938744690891929
# R2_score on training Data :  55.088175538399
# Mean Absolute Error :-  7.311111111111111
# Mean Squared Error :-  72.92888888888889
# Root Mean Squared Error :-  8.53984126836611

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_GBR))
print('R2_score on training Data : ', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :- ', mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error :- ', mean_squared_error(y_test,pred_GBR))
print('Root Mean Squared Error :- ', np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2_score: -0.25431498221559723
# R2_score on training Data :  99.99999870387228
# Mean Absolute Error :-  6.492837151465873
# Mean Squared Error :-  65.62699869913212
# Root Mean Squared Error :-  8.101049234459207

# %%
lasso = Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training Data : ', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :- ', mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error :- ', mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error :- ', np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: 0.5215874316561024
# R2_score on training Data :  85.04513133376163
# Mean Absolute Error :-  4.182848806577064
# Mean Squared Error :-  25.031018081993068
# Root Mean Squared Error :-  5.003100846674297

# %%
rd = Ridge()
rd.fit(x_train,y_train)
pred_ridge=rd.predict(x_test)
pred_train=rd.predict(x_train)
print('R2_score:',r2_score(y_test,pred_ridge))
print('R2_score on training Data : ', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :- ', mean_absolute_error(y_test,pred_ridge))
print('Mean Squared Error :- ', mean_squared_error(y_test,pred_ridge))
print('Root Mean Squared Error :- ', np.sqrt(mean_squared_error(y_test,pred_ridge)))
# Out:
# R2_score: -0.29583470473047324
# R2_score on training Data :  93.88504041432925
# Mean Absolute Error :-  7.027357463206136
# Mean Squared Error :-  67.79935158824378
# Root Mean Squared Error :-  8.234036166318665

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_DTR=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_DTR))
print('R2_score on training Data : ', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :- ', mean_absolute_error(y_test,pred_DTR))
print('Mean Squared Error :- ', mean_squared_error(y_test,pred_DTR))
print('Root Mean Squared Error :- ', np.sqrt(mean_squared_error(y_test,pred_DTR)))
# Out:
# R2_score: 0.044360547428032304
# R2_score on training Data :  100.0
# Mean Absolute Error :-  6.0
# Mean Squared Error :-  50.0
# Root Mean Squared Error :-  7.0710678118654755

# %%
from sklearn.svm import SVR
from sklearn.ensemble import ExtraTreesRegressor

# %%
svr = SVR()
svr.fit(x_train,y_train)
pred_SVR=svr.predict(x_test)
pred_train=svr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_SVR))
print('R2_score on training Data : ', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :- ', mean_absolute_error(y_test,pred_SVR))
print('Mean Squared Error :- ', mean_squared_error(y_test,pred_SVR))
print('Root Mean Squared Error :- ', np.sqrt(mean_squared_error(y_test,pred_SVR)))
# Out:
# R2_score: -1.60627385193404
# R2_score on training Data :  21.93138035807537
# Mean Absolute Error :-  10.186788780893243
# Mean Squared Error :-  136.36282203082052
# Root Mean Squared Error :-  11.677449294722736

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_ETR=etr.predict(x_test)
pred_train=etr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_ETR))
print('R2_score on training Data : ', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :- ', mean_absolute_error(y_test,pred_ETR))
print('Mean Squared Error :- ', mean_squared_error(y_test,pred_ETR))
print('Root Mean Squared Error :- ', np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# R2_score: 0.05756323737612046
# R2_score on training Data :  100.0
# Mean Absolute Error :-  5.733333333333336
# Mean Squared Error :-  49.309222222222246
# Root Mean Squared Error :-  7.022052564757846

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(LR,x,y)
print(score)
print(score.mean())
print('Difference between R2 score and cross validation score is - ',(r2_score(y_test,pred_LR) - score.mean())*100)
# Out:
# [ 0.14840945 -1.44195053  0.5839628   0.73224083  0.56887481]
# 0.11830747243901144
# Difference between R2 score and cross validation score is -  -221.43581911576774

# %%
score1 = cross_val_score(RFR,x,y)
print(score1)
print(score1.mean())
print('Difference between R2 score and cross validation score is - ',(r2_score(y_test,pred_RFR) - score1.mean())*100)
# Out:
# [ 0.1277783  -4.78138947  0.49808666  0.43669607  0.84691215]
# -0.5743832616255019
# Difference between R2 score and cross validation score is -  46.98978675717031

# %%
score2 = cross_val_score(knn,x,y)
print(score2)
print(score2.mean())
print('Difference between R2 score and cross validation score is - ',(r2_score(y_test,pred_knn) - score2.mean())*100)
# Out:
# [ 0.03059091 -2.15842105  0.39121706  0.3144918   0.7692217 ]
# -0.130579915631762
# Difference between R2 score and cross validation score is -  -26.329455345743092

# %%
score3 = cross_val_score(GBR,x,y)
print(score3)
print(score3.mean())
print('Difference between R2 score and cross validation score is - ',(r2_score(y_test,pred_GBR) - score3.mean())*100)
# Out:
# [-0.11816482 -9.29497887  0.45736407  0.58498507  0.73536171]
# -1.5270865660407227
# Difference between R2 score and cross validation score is -  127.27715838251254

# %%
score4 = cross_val_score(lasso,x,y)
print(score4)
print(score4.mean())
print('Difference between R2 score and cross validation score is - ',(r2_score(y_test,pred_lasso) - score4.mean())*100)
# Out:
# [ 0.74349967 -1.26377126  0.74048146  0.73672509  0.90901428]
# 0.3731898466149089
# Difference between R2 score and cross validation score is -  14.839758504119354

# %%
score5 = cross_val_score(rd,x,y)
print(score5)
print(score5.mean())
print('Difference between R2 score and cross validation score is - ',(r2_score(y_test,pred_ridge) - score5.mean())*100)
# Out:
# [ 0.30402575 -1.59567468  0.61577997  0.84383216  0.76525657]
# 0.18664395485630517
# Difference between R2 score and cross validation score is -  -48.247865958677835

# %%
score6 = cross_val_score(dtr,x,y)
print(score6)
print(score6.mean())
print('Difference between R2 score and cross validation score is - ',(r2_score(y_test,pred_DTR) - score6.mean())*100)
# Out:
# [-1.91477273 -9.60526316  0.31827687  0.38688525  0.52830189]
# -2.0573143761743062
# Difference between R2 score and cross validation score is -  210.16749236023387

# %%
score7 = cross_val_score(svr,x,y)
print(score7)
print(score7.mean())
print('Difference between R2 score and cross validation score is - ',(r2_score(y_test,pred_SVR) - score7.mean())*100)
# Out:
# [-0.08608302 -1.13213752 -0.01870582 -0.4517988   0.18013458]
# -0.3017181153356983
# Difference between R2 score and cross validation score is -  -130.4555736598342

# %%
score8 = cross_val_score(etr,x,y)
print(score8)
print(score8.mean())
print('Difference between R2 score and cross validation score is - ',(r2_score(y_test,pred_ETR) - score8.mean())*100)
# Out:
# [ 0.25168    -3.62531974  0.48573593  0.33691082  0.84596521]
# -0.34100555570303887
# Difference between R2 score and cross validation score is -  39.85687930791593

# %% [markdown]
# From the difference of both R2 score and cross validation score computed on R2Score we can conclude that Lasso Regression as our best fitting and best performing model.

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'fit_intercept':[True,False],
            'random_state':[10,20,30],
            'positive':[False,True],
            'max_iter':[-1,0,1]}

# %%
GCV=GridSearchCV(Lasso(), parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'fit_intercept': [True, False], 'max_iter': [-1, 0, 1],
#                          'positive': [False, True],
#                          'random_state': [10, 20, 30]})

# %%
GCV.best_params_
# Out:
# {'fit_intercept': True, 'max_iter': 1, 'positive': True, 'random_state': 10}

# %%
Model= Lasso(fit_intercept=True,max_iter=1,positive=True,random_state=10)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('R2_score: ',r2_score(y_test,pred))
print('Mean Absolute Error :- ',mean_absolute_error(y_test,pred))
print('Mean Squared Error :- ',mean_squared_error(y_test,pred))
print('Root Mean Squared Error :- ',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score:  -0.6527151768412369
# Mean Absolute Error :-  7.005426444240076
# Mean Squared Error :-  86.4716903636193
# Root Mean Squared Error :-  9.299015558843813

# %%
import joblib
import pickle

# %%
pickle.dump(Model,open('Baseball_Case_Study.pkl', 'wb'))

# %%
loaded_model=pickle.load(open('Baseball_Case_Study.pkl', 'rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# -65.2715176841237

# %%
prediction = Model.predict(x_test)
prediction
# Out:
# array([85.1300847 , 74.00176038, 75.7830905 , 84.12981878, 89.61059839,
#        71.43091915, 85.68983718, 88.07245809, 74.10259483])

# %% [markdown]
# This are the win prediction of the Baseball.
