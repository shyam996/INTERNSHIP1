# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\Administrator\Desktop\dataset1-master\census_income.csv')
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.head(10)
# Out:
#    Age          Workclass  Fnlwgt      Education  Education_num  \
# 0   50   Self-emp-not-inc   83311      Bachelors             13
# 1   38            Private  215646        HS-grad              9
# 2   53            Private  234721           11th              7
# 3   28            Private  338409      Bachelors             13
# 4   37            Private  284582        Masters             14
# 5   49            Private  160187            9th              5
# 6   52   Self-emp-not-inc  209642        HS-grad              9
# 7   31            Private   45781        Masters             14
# 8   42            Private  159449      Bachelors             13
# 9   37            Private  280464   Some-college             10
#
#            Marital_status          Occupation    Relationship    Race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
df.nunique().to_frame("No. of unique values")
# Out:
#                 No. of unique values
# Age                               73
# Workclass                          9
# Fnlwgt                         21647
# Education                         16
# Education_num                     16
# Marital_status                     7
# Occupation                        15
# Relationship                       6
# Race                               5
# Sex                                2
# Capital_gain                     119
# Capital_loss                      92
# Hours_per_week                    94
# Native_country                    42
# Income                             2

# %%
print('Total Duplicates Rows are ',df.duplicated().sum())
# Out:
# Total Duplicates Rows are  24

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (32536, 15)

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df['Income'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df['Income'].value_counts()
# Out:
#  <=50K    24697
#  >50K      7839
# Name: Income, dtype: int64

# %% [markdown]
# As there is two unique value present in Target column,it is a classification problem.

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 36    898
# 31    888
# 34    886
# 23    876
# 33    875
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64
#
#
#  Private             22673
#  Self-emp-not-inc     2540
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
#
#
# 123011    13
# 164190    13
# 203488    13
# 121124    12
# 126675    12
#           ..
# 158040     1
# 232784     1
# 325573     1
# 140176     1
# 257302     1
# Name: Fnlwgt, Length: 21647, dtype: int64
#
#
#  HS-grad         10494
#  Some-college     7282
#  Bachelors        5352
#  Masters          1722
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           645
#  Prof-school       576
#  9th               514
#  12th              433
# ...

# %%
categorical_col =[]
for i in df.dtypes.index:
    if df.dtypes[i] == "object":
        categorical_col.append(i)
print('Categorical Columns : ', categorical_col)
print('\n')


numerical_col =[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print('Numerical Columns : ', numerical_col)
print('\n')
# Out:
# Categorical Columns :  ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']
#
#
# Numerical Columns :  ['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32536.000000  3.253600e+04   32536.000000  32536.000000  32536.000000
# mean      38.585536  1.897843e+05      10.081725   1078.410069     87.370912
# std       13.638193  1.055563e+05       2.571622   7388.068465    403.107737
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369932e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32536.000000
# mean        40.440343
# std         12.347079
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# 1) The counts of all columns are same.
#
# 2) The mean > median(50%) in Age,Fnlwgt,Education_num,Capital_gain,Capital_loss,Hours_per_week columns which means data is skewed to right.
#
# 3)There is huge difference between 75% and max that means there is outliers present in data.
#
# 4) We can also notice Standard Deviation which is too much high.

# %%
plt.figure(figsize=(20,25))
plotnumber=1

for column in numerical_col:
    if plotnumber<=6:
        ax=plt.subplot(3,2,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above distribution plots we can say that data looks normal in Age,Education_num,Hours_per_week and data is skewed to right in Fnlwgt,Capital_gain,Capital_loss columns.

# %%
ax = sns.countplot(x='Income', data=df)
print(df['Income'].value_counts())
# Out:
#  <=50K    24697
#  >50K      7839
# Name: Income, dtype: int64

# %% [markdown]
# The Count of Income >50K is lesser than <=50K

# %%
ax = sns.countplot(x='Workclass', data=df)
print(df['Workclass'].value_counts())
# Out:
#  Private             22673
#  Self-emp-not-inc     2540
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %% [markdown]
# The counts of Workclass Private is greater than other types.

# %%
ax = sns.countplot(x='Education', data=df)
print(df['Education'].value_counts())
# Out:
#  HS-grad         10494
#  Some-college     7282
#  Bachelors        5352
#  Masters          1722
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           645
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           332
#  1st-4th           166
#  Preschool          50
# Name: Education, dtype: int64

# %% [markdown]
# The counts of HS-grad in Education is greater than others.

# %%
ax = sns.countplot(x='Education_num',data=df)
print(df['Education_num'].value_counts())
# Out:
# 9     10494
# 10     7282
# 13     5352
# 14     1722
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       645
# 15      576
# 5       514
# 8       433
# 16      413
# 3       332
# 2       166
# 1        50
# Name: Education_num, dtype: int64

# %% [markdown]
# The counts of Education_num 9 is higher than others.

# %%
ax = sns.countplot(x='Marital_status',data=df)
print(df['Marital_status'].value_counts())
# Out:
#  Married-civ-spouse       14970
#  Never-married            10666
#  Divorced                  4441
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %% [markdown]
# The count of Married-civ-spouse is higher than other types of Marital_status.

# %%
ax = sns.countplot(x='Occupation',data=df)
print(df['Occupation'].value_counts())
# Out:
#  Prof-specialty       4136
#  Craft-repair         4094
#  Exec-managerial      4065
#  Adm-clerical         3767
#  Sales                3650
#  Other-service        3291
#  Machine-op-inspct    2000
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1369
#  Farming-fishing       992
#  Tech-support          927
#  Protective-serv       649
#  Priv-house-serv       147
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %% [markdown]
# The counts of Prof-speciality is higher than other types of Occupation.

# %%
ax = sns.countplot(x='Relationship',data=df)
print(df['Relationship'].value_counts())
# Out:
#  Husband           13187
#  Not-in-family      8291
#  Own-child          5064
#  Unmarried          3445
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %% [markdown]
# The counts of Husband is higher than other types of Relationship.

# %%
ax = sns.countplot(x='Race',data=df)
print(df['Race'].value_counts())
# Out:
#  White                 27794
#  Black                  3122
#  Asian-Pac-Islander     1038
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %% [markdown]
# The counts of White is higher than other types of Race.

# %%
ax = sns.countplot(x='Sex',data=df)
print(df['Sex'].value_counts())
# Out:
#  Male      21774
#  Female    10762
# Name: Sex, dtype: int64

# %% [markdown]
# The counts of Male is higher than Female in Sex.

# %%
ax = sns.countplot(x='Native_country',data=df)
print(df['Native_country'].value_counts())
# Out:
#  United-States                 29152
#  Mexico                          639
#  ?                               582
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Japan                            62
#  Guatemala                        62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %% [markdown]
# The counts of United States is higher than other types of Native_country

# %%
sns.catplot(x='Education', col='Income', data=df , kind='count')
plt.show()

# %%
sns.catplot(x='Education_num', col='Income', data=df , kind='count')
plt.show()

# %%
sns.catplot(x='Workclass', col='Income', data=df , kind='count')
plt.show()

# %%
sns.catplot(x='Marital_status', col='Income', data=df , kind='count')

sns.catplot(x='Occupation', col='Income', data=df , kind='count')
plt.show()

# %%
sns.catplot(x='Relationship', col='Income', data=df , kind='count')

sns.catplot(x='Race', col='Income', data=df , kind='count')
plt.show()

# %%
sns.catplot(x='Sex', col='Income', data=df , kind='count')

sns.catplot(x='Native_country', col='Income', data=df , kind='count')
plt.show()

# %%
plt.figure(figsize=(20,15))
plotnumber=1

for col in numerical_col:
    if plotnumber<=6:
        ax=plt.subplot(3,2,plotnumber)
        sns.boxplot(df[col])
        plt.xlabel(col,fontsize=15)
    plotnumber+=1
plt.show()

# %% [markdown]
# The columns Education_num is categorical col so we will not remove outliers from it, rest all the columns having outliers we will remove it.

# %%
df.skew()
# Out:
# Age                0.557657
# Fnlwgt             1.447695
# Education_num     -0.309454
# Capital_gain      11.949245
# Capital_loss       4.592622
# Hours_per_week     0.228752
# dtype: float64

# %% [markdown]
# The columns Fnlwgt,Capital_gain,Capital_loss having skewness rest looks normal.

# %%
df['Fnlwgt'] =np.cbrt(df['Fnlwgt'])
df['Capital_gain'] =np.cbrt(df['Capital_gain'])
df['Capital_loss'] =np.cbrt(df['Capital_loss'])

# %%
df.skew()
# Out:
# Age               0.557657
# Fnlwgt           -0.163720
# Education_num    -0.309454
# Capital_gain      4.098390
# Capital_loss      4.335154
# Hours_per_week    0.228752
# dtype: float64

# %% [markdown]
# We have reduced skewness in Fnlwgt and Capital_gain, Capital_loss having skewness but still reduced.

# %%
plt.figure(figsize=(20,25))
plotnumber=1

for column in numerical_col:
    if plotnumber<=6:
        ax=plt.subplot(3,2,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# From this distplot we ca say that data looks normal in all columns except having skewness in Capital_gain and Capital_loss columns.

# %% [markdown]
# ## Encoding Categorical columns

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#        Age  Workclass     Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0  43.675121        9.0             13             2.0
# 1       38        4.0  59.967204       11.0              9             0.0
# 2       53        4.0  61.685627        1.0              7             2.0
# 3       28        4.0  69.686283        9.0             13             2.0
# 4       37        4.0  65.776255       12.0             14             2.0
# ...    ...        ...        ...        ...            ...             ...
# 32555   27        4.0  63.603506        7.0             12             2.0
# 32556   40        4.0  53.644440       11.0              9             2.0
# 32557   58        4.0  53.357498       11.0              9             6.0
# 32558   22        4.0  58.625222       11.0              9             4.0
# 32559   52        5.0  66.032965       11.0              9             2.0
#
# ...

# %% [markdown]
# After Encoding Categorical columns,We have converted from object datatypes into float datatypes

# %%
from scipy.stats import zscore
out_features=df[['Age','Fnlwgt','Capital_gain','Capital_loss','Hours_per_week']]
z=np.abs(zscore(out_features))
z
# Out:
#             Age    Fnlwgt  Capital_gain  Capital_loss  Hours_per_week
# 0      0.836961  1.087390      0.278735      0.220644        2.222450
# 1      0.042934  0.417215      0.278735      0.220644        0.035664
# 2      1.056935  0.575915      0.278735      0.220644        0.035664
# 3      0.776180  1.314791      0.278735      0.220644        0.035664
# 4      0.116259  0.953692      0.278735      0.220644        0.035664
# ...         ...       ...           ...           ...             ...
# 32555  0.849505  0.753035      0.278735      0.220644        0.197648
# 32556  0.103715  0.166704      0.278735      0.220644        0.035664
# 32557  1.423558  0.193204      0.278735      0.220644        0.035664
# 32558  1.216128  0.293281      0.278735      0.220644        1.655506
# 32559  0.983611  0.977400      3.823742      0.220644        0.035664
#
# [32536 rows x 5 columns]

# %%
np.where(z>3)
# Out:
# (array([    7,     9,    22, ..., 32506, 32513, 32535], dtype=int64),
#  array([2, 4, 3, ..., 4, 2, 2], dtype=int64))

# %%
df_1 = df[(z<3).all(axis=1)]
df_1.shape
# Out:
# (29316, 15)

# %%
print('OLd Data Frame- ',df.shape[0])
print('New Data Frame- ',df_1.shape[0])
# Out:
# OLd Data Frame-  32536
# New Data Frame-  29316

# %%
print('Data Loss Percentage- ',((df.shape[0] - df_1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage-  9.896729776247849

# %%
df=df_1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29316 entries, 0 to 32558
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             29316 non-null  int64
#  1   Workclass       29316 non-null  float64
#  2   Fnlwgt          29316 non-null  float64
#  3   Education       29316 non-null  float64
#  4   Education_num   29316 non-null  int64
#  5   Marital_status  29316 non-null  float64
#  6   Occupation      29316 non-null  float64
#  7   Relationship    29316 non-null  float64
#  8   Race            29316 non-null  float64
#  9   Sex             29316 non-null  float64
#  10  Capital_gain    29316 non-null  float64
#  11  Capital_loss    29316 non-null  float64
#  12  Hours_per_week  29316 non-null  int64
#  13  Native_country  29316 non-null  float64
#  14  Income          29316 non-null  float64
# dtypes: float64(12), int64(3)
# memory usage: 3.6 MB

# %%
df.describe()
# Out:
#                 Age     Workclass        Fnlwgt     Education  Education_num  \
# count  29316.000000  29316.000000  29316.000000  29316.000000   29316.000000
# mean      37.916087      3.856085     55.399348     10.266032       9.953984
# std       13.350867      1.447139     10.678421      3.927226       2.517257
# min       17.000000      0.000000     23.074115      0.000000       1.000000
# 25%       27.000000      4.000000     49.019429      9.000000       9.000000
# 50%       36.000000      4.000000     56.332997     11.000000      10.000000
# 75%       47.000000      4.000000     61.867563     12.000000      12.000000
# max       79.000000      8.000000     87.738766     15.000000      16.000000
#
#        Marital_status    Occupation  Relationship          Race           Sex  \
# count    29316.000000  29316.000000  29316.000000  29316.000000  29316.000000
# mean         2.639071      6.534896      1.495873      3.659299      0.657627
# ...

# %% [markdown]
# After Encoding Categorical columns we can see all columns details here. The counts of all columns are same that means there are no null values in dataset.We have removed the outliers and now description of data looks normal.

# %%
df.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.004213 -0.065643  -0.016794       0.015180
# Workclass       0.004213   1.000000 -0.016072   0.019744       0.047915
# Fnlwgt         -0.065643  -0.016072  1.000000  -0.026973      -0.046077
# Education      -0.016794   0.019744 -0.026973   1.000000       0.368346
# Education_num   0.015180   0.047915 -0.046077   0.368346       1.000000
# Marital_status -0.284105  -0.058992  0.028838  -0.034928      -0.056110
# Occupation     -0.016549   0.255399 -0.003603  -0.024399       0.101515
# Relationship   -0.265266  -0.088579  0.008418  -0.007166      -0.082026
# Race            0.021022   0.047393 -0.010032   0.013964       0.028368
# Sex             0.080692   0.090686  0.026347  -0.033148      -0.001909
# Capital_gain    0.075670  -0.000508 -0.004875   0.010872       0.032333
# Capital_loss    0.006674  -0.006724 -0.003551   0.002750       0.009206
# ...

# %%
df_corr = df.corr().abs()
plt.figure(figsize=(25,20))
sns.heatmap(df_corr,annot=True,annot_kws={'size':20})
# Out:
# <AxesSubplot:>

# %% [markdown]
# From this above heatmap we can say that there is no such positive correlation between target and features , and there is no such features has high collinearity with others.

# %% [markdown]
# ## Correlation between label and features

# %%
plt.figure(figsize=(35,15))
df.corr()['Income'].sort_values(ascending=False).drop(['Income']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title("Correlation between label and features using barplot",fontsize=20)
plt.show()

# %% [markdown]
# From the above bar plot we can say that Fnlwgt has very less correlation with Target column.

# %% [markdown]
# ## Separating Features and Label

# %%
x= df.drop('Income',axis=1)
y=df['Income']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.905119   1.481510 -1.097955  -0.322379       1.210074
# 1      0.006285   0.099449  0.427772   0.186895      -0.378984
# 2      1.129827   0.099449  0.588700  -2.359475      -1.173513
# 3     -0.742742   0.099449  1.337949  -0.322379       1.210074
# 4     -0.068617   0.099449  0.971781   0.441532       1.607339
# ...         ...        ...       ...        ...            ...
# 29311 -1.192159   0.099449  1.151005   1.205443       0.018280
# 29312 -0.817645   0.099449  0.768306  -0.831653       0.812810
# 29313  0.156091   0.099449 -0.164344   0.186895      -0.378984
# 29314  1.504341   0.099449 -0.191216   0.186895      -0.378984
# 29315 -1.192159   0.099449  0.302098   0.186895      -0.378984
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0           -0.419697   -0.598276     -0.931923  0.398589  0.721539
# 1           -1.733159   -0.126244     -0.308927  0.398589  0.721539
# ...

# %% [markdown]
# We have scaled the data using Standard Scalarization method to overcome the issue of biasness.

# %% [markdown]
# ## VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i)
                    for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values        Features
# 0     1.168473             Age
# 1     1.090538       Workclass
# 2     1.011731          Fnlwgt
# 3     1.168096       Education
# 4     1.202886   Education_num
# 5     1.138298  Marital_status
# 6     1.089969      Occupation
# 7     1.655765    Relationship
# 8     1.036194            Race
# 9     1.532800             Sex
# 10    1.009653    Capital_gain
# 11    1.000804    Capital_loss
# 12    1.135784  Hours_per_week
# 13    1.027501  Native_country

# %% [markdown]
# By checking VIF values all are less than 10 that means there is no multicollinearity exists.We can go for Model Building

# %%
y.value_counts()
# Out:
# 0.0    23499
# 1.0     5817
# Name: Income, dtype: int64

# %% [markdown]
# Here we can see data is not balanced,since it is a classification problem we will balance the data using oversampling method

# %% [markdown]
# ## OverSampling

# %%
from imblearn.over_sampling import SMOTE
SM = SMOTE()
x,y = SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0.0    23499
# 1.0    23499
# Name: Income, dtype: int64

# %% [markdown]
# Now the data is imbalanced .Now we can build machine learning classification models.

# %% [markdown]
# ## Creating Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=420)

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.9033333333333333
# [[6325  798]
#  [ 565 6412]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.89      0.90      7123
#          1.0       0.89      0.92      0.90      6977
#
#     accuracy                           0.90     14100
#    macro avg       0.90      0.90      0.90     14100
# weighted avg       0.90      0.90      0.90     14100

# %%
LR =LogisticRegression()
LR.fit(x_train,y_train)
predLR= LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.75
# [[5169 1954]
#  [1571 5406]]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.73      0.75      7123
#          1.0       0.73      0.77      0.75      6977
#
#     accuracy                           0.75     14100
#    macro avg       0.75      0.75      0.75     14100
# weighted avg       0.75      0.75      0.75     14100

# %%
svc = SVC()
svc.fit(x_train,y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8290780141843972
# [[5371 1752]
#  [ 658 6319]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.75      0.82      7123
#          1.0       0.78      0.91      0.84      6977
#
#     accuracy                           0.83     14100
#    macro avg       0.84      0.83      0.83     14100
# weighted avg       0.84      0.83      0.83     14100

# %%
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB = GB.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.8639716312056738
# [[5837 1286]
#  [ 632 6345]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.82      0.86      7123
#          1.0       0.83      0.91      0.87      6977
#
#     accuracy                           0.86     14100
#    macro avg       0.87      0.86      0.86     14100
# weighted avg       0.87      0.86      0.86     14100

# %%
ABC = AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC = ABC.predict(x_test)
print(accuracy_score(y_test,predABC))
print(confusion_matrix(y_test,predABC))
print(classification_report(y_test,predABC))
# Out:
# 0.8508510638297873
# [[5833 1290]
#  [ 813 6164]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.82      0.85      7123
#          1.0       0.83      0.88      0.85      6977
#
#     accuracy                           0.85     14100
#    macro avg       0.85      0.85      0.85     14100
# weighted avg       0.85      0.85      0.85     14100

# %%
BC = BaggingClassifier()
BC.fit(x_train,y_train)
predBC = BC.predict(x_test)
print(accuracy_score(y_test,predBC))
print(confusion_matrix(y_test,predBC))
print(classification_report(y_test,predBC))
# Out:
# 0.8847517730496454
# [[6318  805]
#  [ 820 6157]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.89      0.89      7123
#          1.0       0.88      0.88      0.88      6977
#
#     accuracy                           0.88     14100
#    macro avg       0.88      0.88      0.88     14100
# weighted avg       0.88      0.88      0.88     14100

# %%
ET = ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET = ET.predict(x_test)
print(accuracy_score(y_test,predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.9095035460992907
# [[6307  816]
#  [ 460 6517]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.89      0.91      7123
#          1.0       0.89      0.93      0.91      6977
#
#     accuracy                           0.91     14100
#    macro avg       0.91      0.91      0.91     14100
# weighted avg       0.91      0.91      0.91     14100

# %%
DT = DecisionTreeClassifier()
DT.fit(x_train,y_train)
predDT = DT.predict(x_test)
print(accuracy_score(y_test,predDT))
print(confusion_matrix(y_test,predDT))
print(classification_report(y_test,predDT))
# Out:
# 0.8542553191489362
# [[6056 1067]
#  [ 988 5989]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.85      0.85      7123
#          1.0       0.85      0.86      0.85      6977
#
#     accuracy                           0.85     14100
#    macro avg       0.85      0.85      0.85     14100
# weighted avg       0.85      0.85      0.85     14100

# %% [markdown]
# ## Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
score1=cross_val_score(RFC,x,y)
print(score1)
print(score1.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predRFC) - score1.mean())
# Out:
# [0.8206383  0.9043617  0.92553191 0.93435472 0.92988616]
# 0.9029545583165254
# Difference between Accuracy score and cross validation score is -  0.0003787750168079418

# %%
score2=cross_val_score(LR,x,y)
print(score2)
print(score2.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predLR) - score2.mean())
# Out:
# [0.74297872 0.75010638 0.75351064 0.75625066 0.74965422]
# 0.750500125635819
# Difference between Accuracy score and cross validation score is -  -0.0005001256358190265

# %%
score3=cross_val_score(GB,x,y)
print(score3)
print(score3.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predGB) - score3.mean())
# Out:
# [0.80287234 0.86329787 0.87574468 0.8825407  0.8788169 ]
# 0.8606544969700263
# Difference between Accuracy score and cross validation score is -  0.003317134235647501

# %%
score4=cross_val_score(svc,x,y)
print(score4)
print(score4.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predsvc) - score4.mean())
# Out:
# [0.82138298 0.82819149 0.83382979 0.83785509 0.83732312]
# 0.8317164931534139
# Difference between Accuracy score and cross validation score is -  -0.0026384789690167

# %%
score5=cross_val_score(ABC,x,y)
print(score5)
print(score5.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predABC) - score5.mean())
# Out:
# [0.80010638 0.84202128 0.85723404 0.86232578 0.85966592]
# 0.8442706806744946
# Difference between Accuracy score and cross validation score is -  0.006580383155292635

# %%
score6=cross_val_score(BC,x,y)
print(score6)
print(score6.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predBC) - score6.mean())
# Out:
# [0.77351064 0.88914894 0.91446809 0.92073625 0.92307692]
# 0.884188166237694
# Difference between Accuracy score and cross validation score is -  0.0005636068119513338

# %%
score7=cross_val_score(ET,x,y)
print(score7)
print(score7.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predET) - score7.mean())
# Out:
# [0.87159574 0.91382979 0.93031915 0.93573784 0.93020534]
# 0.9163375732592648
# Difference between Accuracy score and cross validation score is -  -0.006834027159974054

# %%
score8=cross_val_score(DT,x,y)
print(score8)
print(score8.mean())
print("Difference between Accuracy score and cross validation score is - ",accuracy_score(y_test,predDT) - score8.mean())
# Out:
# [0.74861702 0.86117021 0.87904255 0.89041387 0.88754123]
# 0.8533569777681193
# Difference between Accuracy score and cross validation score is -  0.0008983413808169027

# %% [markdown]
# Logistic Regression is the best Model as the difference between accuracy score and cross validation score is least.

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'fit_intercept':[True,False],
        'solver':['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
        'n_jobs':[-2,-1,1],
        'random_state':[10,50,100]}

# %%
GCV=GridSearchCV(LogisticRegression(),parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'fit_intercept': [True, False], 'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 100],
#                          'solver': ['lbfgs', 'liblinear', 'newton-cg',
#                                     'newton-cholesky', 'sag', 'saga']})

# %%
GCV.best_params_
# Out:
# {'fit_intercept': True,
#  'n_jobs': -2,
#  'random_state': 10,
#  'solver': 'liblinear'}

# %%
Final_model=LogisticRegression( fit_intercept=True,n_jobs=-2,random_state=10,solver='liblinear')
Final_model.fit(x_train,y_train)
pred =Final_model.predict(x_test)
acc = accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 75.0

# %% [markdown]
# The accuracy for the Final Model LogisticRegression is 75%

# %%
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import plot_roc_curve

# %%
dis = plot_roc_curve(DT,x_test,y_test)
plot_roc_curve(LR,x_test,y_test,ax=dis.ax_)
plot_roc_curve(RFC,x_test,y_test,ax=dis.ax_)
plot_roc_curve(GB,x_test,y_test,ax=dis.ax_)
plot_roc_curve(ABC,x_test,y_test,ax=dis.ax_)
plot_roc_curve(svc,x_test,y_test,ax=dis.ax_)
plot_roc_curve(BC,x_test,y_test,ax=dis.ax_)
plot_roc_curve(ET,x_test,y_test,ax=dis.ax_)

plt.legend(prop={'size':10}, loc='lower right')
plt.show()

# %% [markdown]
# This is ROC_curve plot for all models for test data score for all models.

# %%
dis = plot_roc_curve(DT,x_train,y_train)
plot_roc_curve(LR,x_train,y_train,ax=dis.ax_)
plot_roc_curve(RFC,x_train,y_train,ax=dis.ax_)
plot_roc_curve(GB,x_train,y_train,ax=dis.ax_)
plot_roc_curve(ABC,x_train,y_train,ax=dis.ax_)
plot_roc_curve(svc,x_train,y_train,ax=dis.ax_)
plot_roc_curve(BC,x_train,y_train,ax=dis.ax_)
plot_roc_curve(ET,x_train,y_train,ax=dis.ax_)

plt.legend(prop={'size':10}, loc='lower right')
plt.show()

# %% [markdown]
# This is ROC_curve plot for all models for train data score for all models.

# %% [markdown]
# ## Saving The Model

# %%
import joblib
import pickle

# %%
pickle.dump(Final_model,open('Census_Income.pkl', 'wb'))

# %%
loaded_model = pickle.load(open('Census_Income.pkl', 'rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 75.0

# %%
prediction =Final_model.predict(x_test)
prediction
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %% [markdown]
# This is the predicted value of the Income.
